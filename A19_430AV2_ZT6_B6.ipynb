# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_2}-\bar{X_1}$$
#
# Let Group 1 be 6hSleeping whole brain C57/BL6 strain (B6) Expression values and Group 2 be 6hSD whole brain C57/BL6 strain (B6) Expression values
#
# (S mean - SD mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviation} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and file IO
import numpy as np # numerical calculations
# %cd /Users/Ella1/Desktop/data sets 430AV2
# Out:
# /Users/Ella1/Desktop/data sets 430AV2

# %%
prefix = '430AV2_ZT6_B6_'   # define a prefix to add to column names (mB6ing indexing easier later)

# %%
# import the data file to a data frame 'df'
df=pd.read_table('DATASET-GSE9442.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.shape
# Out:
# (45101, 87)

# %%
# remove probes that are know to cross-hybridise to more than one target
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (40569, 87)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into S and SD groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239868_AK_S_ZT6.CEL',
#        'GSM239869_AK_S_ZT6.CEL', 'GSM239870_AK_S_ZT6.CEL', 'avg-AK_S_ZT6',
#        'log_fold-AK_S_ZT6_vs_AK_SD_ZT6', 'fold-AK_S_ZT6_vs_AK_SD_ZT6',
#        'rawp-AK_S_ZT6_vs_AK_SD_ZT6', 'adjp-AK_S_ZT6_vs_AK_SD_ZT6',
#        'GSM239871_AK_S_ZT12.CEL', 'GSM239872_AK_S_ZT12.CEL',
#        'GSM239873_AK_S_ZT12.CEL', 'avg-AK_S_ZT12',
#        'log_fold-AK_S_ZT12_vs_AK_SD_ZT12', 'fold-AK_S_ZT12_vs_AK_SD_ZT12',
#        'rawp-AK_S_ZT12_vs_AK_SD_ZT12', 'adjp-AK_S_ZT12_vs_AK_SD_ZT12',
#        'GSM239880_AK_SD_ZT6.CEL', 'GSM239881_AK_SD_ZT6.CEL',
#        'GSM239882_AK_SD_ZT6.CEL', 'avg-AK_SD_ZT6', 'GSM239883_AK_SD_ZT12.CEL',
#        'GSM239884_AK_SD_ZT12.CEL', 'GSM239885_AK_SD_ZT12.CEL',
#        'avg-AK_SD_ZT12', 'GSM239891_B6_S_ZT6.CEL',
#        'GSM239892._B6_S_ZT6CEL.CEL', 'GSM239893_B6_S_ZT6.CEL', 'avg-B6_S_ZT6',
#        'log_fold-B6_S_ZT6_vs_B6_SD_ZT6', 'fold-B6_S_ZT6_vs_B6_SD_ZT6',
#        'rawp-B6_S_ZT6_vs_B6_SD_ZT6', 'adjp-B6_S_ZT6_vs_B6_SD_ZT6',
#        'GSM239894_B6_S_ZT12.CEL', 'GSM239895_B6_S_ZT12.CEL',
#        'GSM239896_B6_S_ZT12.CEL', 'avg-B6_S_ZT12',
#        'log_fold-B6_S_ZT12_vs_B6_SD_ZT12', 'fold-B6_S_ZT12_vs_B6_SD_ZT12',
#        'rawp-B6_S_ZT12_vs_B6_SD_ZT12', 'adjp-B6_S_ZT12_vs_B6_SD_ZT12',
#        'GSM239903_B6_SD_ZT6.CEL', 'GSM239904_B6_SD_ZT6.CEL',
#        'GSM239905_B6_SD_ZT6.CEL', 'avg-B6_SD_ZT6', 'GSM239906_B6_SD_ZT12.CEL',
#        'GSM239907._B6_SD_ZT12CEL.CEL', 'GSM239908_B6_SD_ZT12.CEL',
#        'avg-B6_SD_ZT12', 'GSM239915_D2_S_ZT6.CEL', 'GSM239916_D2_S_ZT6.CEL',
#        'GSM239917_D2_S_ZT6.CEL', 'avg-D2_S_ZT6',
#        'log_fold-D2_S_ZT6_vs_D2_SD_ZT6', 'fold-D2_S_ZT6_vs_D2_SD_ZT6',
#        'rawp-D2_S_ZT6_vs_D2_SD_ZT6', 'adjp-D2_S_ZT6_vs_D2_SD_ZT6',
#        'GSM239918_D2_S_ZT12.CEL', 'GSM239919_D2_S_ZT12.CEL',
#        'GSM239920_D2_S_ZT12.CEL', 'avg-D2_S_ZT12',
#        'log_fold-D2_S_ZT12_vs_D2_SD_ZT12', 'fold-D2_S_ZT12_vs_D2_SD_ZT12',
#        'rawp-D2_S_ZT12_vs_D2_SD_ZT12', 'adjp-D2_S_ZT12_vs_D2_SD_ZT12',
#        'GSM239927_D2_SD_ZT6.CEL', 'GSM239928_D2_SD_ZT6.CEL',
#        'GSM239929_D2_SD_ZT6.CEL', 'avg-D2_SD_ZT6', 'GSM239930_D2_SD_ZT12.CEL',
#        'GSM239931_D2_SD_ZT12.CEL', 'GSM239932_D2_SD_ZT12.CEL',
#        'avg-D2_SD_ZT12', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold'],
#       dtype='object')

# %%
# define regular expressions for sleep (S) and sleep dep (SD) filters 
s_filt ='B6_S_ZT6.CEL'
sd_filt ='B6_SD_ZT6.CEL'

# %%
df_s=df.filter(regex= s_filt)
df_s.head()
# Out:
#               GSM239891_B6_S_ZT6.CEL  GSM239893_B6_S_ZT6.CEL
# Probesets
# 1427138_at                   6.23366                 6.25013
# 1425600_a_at                 7.54536                 7.24677
# 1457168_at                   4.71756                 4.38148
# 1450135_at                   4.89215                 5.05446
# 1424014_at                   7.96183                 8.10473

# %%
df_sd=df.filter(regex= sd_filt)
df_sd.head()
# Out:
#               GSM239903_B6_SD_ZT6.CEL  GSM239904_B6_SD_ZT6.CEL  \
# Probesets
# 1427138_at                    6.02424                  6.04533
# 1425600_a_at                  7.50737                  7.62468
# 1457168_at                    4.46026                  4.65893
# 1450135_at                    5.00071                  5.38261
# 1424014_at                    8.16797                  8.16044
#
#               GSM239905_B6_SD_ZT6.CEL
# Probesets
# 1427138_at                    6.47572
# 1425600_a_at                  7.23338
# 1457168_at                    4.72749
# 1450135_at                    4.97833
# 1424014_at                    8.19058

# %% [markdown]
# ## Calculations

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=sd_filt).mean(axis=1) - df.filter(regex=s_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at     -0.060132
# 1425600_a_at    0.059078
# 1457168_at      0.066040
# 1450135_at      0.147245
# 1424014_at      0.139717
# Name: 430AV2_ZT6_B6_Enrich, dtype: float64

# %%
# Calculating Pooled StDev
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

StdevS = (Scount-1) * df.filter(regex=s_filt).var(axis=1)
StdevSD = (SDcount-1) * df.filter(regex=sd_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevS+StdevSD)/(Scount+ SDcount-2))

# %%
# Calculating Cohen's d
df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
#df[prefix+'poolStDev'].head()
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at     -0.288892
# 1425600_a_at    0.289161
# 1457168_at      0.371108
# 1450135_at      0.747408
# 1424014_at      2.339214
# Name: 430AV2_ZT6_B6_Cohens_d, dtype: float64

# %%
# Calculating J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(Scount+SDcount-1)))

# %%
# Calculating Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at     -0.234725
# 1425600_a_at    0.234943
# 1457168_at      0.301526
# 1450135_at      0.607269
# 1424014_at      1.900611
# Name: 430AV2_ZT6_B6_Hedges_g, dtype: float64

# %%
# Calculating Var_d
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

Ftop1 = Scount + SDcount
Ftop2 = Scount * SDcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(Scount + SDcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check output
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.841679
# 1425600_a_at    0.841695
# 1457168_at      0.847105
# 1450135_at      0.889195
# 1424014_at      1.380526
# Name: 430AV2_ZT6_B6_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
# Calculating SEg
df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by= '430AV2_ZT6_B6_Hedges_g', ascending=False, inplace=True)
df
# Out:
#                            Symbol  \
# Probesets
# 1419807_at             D4Ertd335e
# 1422287_at                  Phxr2
# 1420418_at                   Syt2
# 1460737_at                  Igbp1
# 1453077_a_at               Snapc3
# 1444997_at                    NaN
# 1427154_at                   Krt2
# 1437609_at                  Ube2u
# 1422943_a_at                Hspb1
# 1436737_a_at               Sorbs1
# 1423157_at                Gnpnat1
# 1423151_at                Dnajb11
# 1416308_at                   Ugdh
# 1437247_at    Fosl2 /// LOC634417
# 1448129_at                  Arpc5
# 1451581_at                  Saps2
# 1417603_at                   Per2
# 1435250_at                  Ints8
# 1458261_at                    NaN
# 1457883_at                    NaN
# 1433191_at          A430105P17Rik
# 1428112_at                  Armet
# 1424147_at                  Ahsa1
# 1443934_at          9230110C19Rik
# 1434022_at                 Zbtb33
# 1422196_at                  Htr5b
# 1429746_at                 Efcab9
# 1421911_at                  Stat2
# 1421742_at                   Gdi2
# 1430942_at          8430437O03Rik
# ...                           ...
# 1439602_at                    NaN
# 1431578_at                 Wbp2nl
# 1435854_at                 Opalin
# 1443183_at                  Huwe1
# 1436969_at          4922501L14Rik
# 1446387_at                    NaN
# 1424562_a_at              Slc25a4
# 1424251_a_at               Hnrpdl
# 1416621_at                  Llgl1
# 1431808_a_at                Itih4
# 1456884_at          6820445E23Rik
# 1449400_at                    Csl
# 1443599_at                    NaN
# 1417443_at                Fam151a
# 1441883_at          0610010O12Rik
# 1445524_at                    NaN
# 1454435_at                    NaN
# 1457736_at                 Vps37d
# 1450262_at                  Clcf1
# 1438434_at              Arhgap11a
# 1424355_a_at                Sin3b
# 1429286_at          1190003M12Rik
# 1438568_at                 Mrgpre
# 1428747_at               Trnau1ap
# 1418052_at                    Mvk
# 1434730_at               AI854517
# 1452188_at                  Maml1
# 1419072_at                  Gstm7
# 1449060_at    Kif2c /// LOC631653
# 1438604_at                 Atp8b3
#
#                                                      Definition  \
# Probesets
# 1419807_at         DNA segment, Chr 4, ERATO Doi 335, expressed
# 1422287_at                            per-hexamer repeat gene 2
# 1420418_at                                     synaptotagmin II
# 1460737_at             immunoglobulin (CD79A) binding protein 1
# 1453077_a_at  small nuclear RNA activating complex, polypept...
# 1444997_at                                                  NaN
# 1427154_at                                            keratin 2
# 1437609_at    ubiquitin-conjugating enzyme E2U (putative) [S...
# 1422943_a_at                               heat shock protein 1
# 1436737_a_at                 sorbin and SH3 domain containing 1
# 1423157_at          glucosamine-phosphate N-acetyltransferase 1
# 1423151_at         DnaJ (Hsp40) homolog, subfamily B, member 11
# 1416308_at                            UDP-glucose dehydrogenase
# 1437247_at    fos-like antigen 2 [Source:MGI Symbol;Acc:MGI:...
# 1448129_at         actin related protein 2/3 complex, subunit 5
# 1451581_at          protein phosphatase 6, regulatory subunit 2
# 1417603_at                        period homolog 2 (Drosophila)
# 1435250_at                         integrator complex subunit 8
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                           RIKEN cDNA A430105P17 gene
# 1428112_at         arginine-rich, mutated in early stage tumors
# 1424147_at       AHA1, activator of heat shock protein ATPase 1
# 1443934_at    RIKEN cDNA 9230110C19 gene [Source:MGI Symbol;...
# 1434022_at    zinc finger and BTB domain containing 33 [Sour...
# 1422196_at          5-hydroxytryptamine (serotonin) receptor 5B
# 1429746_at    EF-hand calcium binding domain 9 [Source:MGI S...
# 1421911_at    signal transducer and activator of transcripti...
# 1421742_at    guanosine diphosphate (GDP) dissociation inhib...
# 1430942_at                           RIKEN cDNA 8430437O03 gene
# ...                                                         ...
# 1439602_at         fidgetin [Source:MGI Symbol;Acc:MGI:1890647]
# 1431578_at    WBP2 N-terminal like [Source:MGI Symbol;Acc:MG...
# 1435854_at    oligodendrocytic myelin paranodal and inner lo...
# 1443183_at    HECT, UBA and WWE domain containing 1 [Source:...
# 1436969_at    RIKEN cDNA 4922501L14 gene [Source:MGI Symbol;...
# 1446387_at                                                  NaN
# 1424562_a_at  solute carrier family 25 (mitochondrial carrie...
# 1424251_a_at     heterogeneous nuclear ribonucleoprotein D-like
# 1416621_at           lethal giant larvae homolog 1 (Drosophila)
# 1431808_a_at       inter alpha-trypsin inhibitor, heavy chain 4
# 1456884_at                           RIKEN cDNA 6820445E23 gene
# 1449400_at                                citrate synthase like
# 1443599_at    predicted gene 10702 [Source:MGI Symbol;Acc:MG...
# 1417443_at                               cDNA sequence BC026682
# 1441883_at                           RIKEN cDNA 0610010O12 gene
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at    vacuolar protein sorting 37D (yeast) [Source:M...
# 1450262_at                 cardiotrophin-like cytokine factor 1
# 1438434_at    Rho GTPase activating protein 11A [Source:MGI ...
# 1424355_a_at           transcriptional regulator, SIN3B (yeast)
# 1429286_at     gastrokine 3 [Source:MGI Symbol;Acc:MGI:1916138]
# 1438568_at    MAS-related GPR, member E [Source:MGI Symbol;A...
# 1428747_at    tRNA selenocysteine 1 associated protein 1 [So...
# 1418052_at                                    mevalonate kinase
# 1434730_at                                                  NaN
# 1452188_at                       mastermind like 1 (Drosophila)
# 1419072_at                      glutathione S-transferase, mu 7
# 1449060_at                             kinesin family member 2C
# 1438604_at    ATPase, class I, type 8B, member 3 [Source:MGI...
#
#                                          Ensembl_id     Entrez_id Unigene_id  \
# Probesets
# 1419807_at                                      NaN         52302        NaN
# 1422287_at                       ENSMUSG00000055108         18687        NaN
# 1420418_at                       ENSMUSG00000026452         20980        NaN
# 1460737_at                       ENSMUSG00000031221         18518        NaN
# 1453077_a_at                     ENSMUSG00000028483         77634        NaN
# 1444997_at                                      NaN           NaN        NaN
# 1427154_at                       ENSMUSG00000064201         16681        NaN
# 1437609_at                       ENSMUSG00000069733        381534        NaN
# 1422943_a_at  ENSMUSG00000004951|ENSMUSG00000078915         15507        NaN
# 1436737_a_at                     ENSMUSG00000025006         20411        NaN
# 1423157_at                       ENSMUSG00000037722         54342        NaN
# 1423151_at                       ENSMUSG00000004460         67838        NaN
# 1416308_at                       ENSMUSG00000029201         22235        NaN
# 1437247_at                       ENSMUSG00000029135  14284|634417        NaN
# 1448129_at                       ENSMUSG00000008475         67771        NaN
# 1451581_at                       ENSMUSG00000036561         71474        NaN
# 1417603_at                       ENSMUSG00000055866         18627        NaN
# 1435250_at                       ENSMUSG00000040738         72656        NaN
# 1458261_at                                      NaN           NaN        NaN
# 1457883_at                                      NaN           NaN  Mm.372465
# 1433191_at                                      NaN         77768        NaN
# 1428112_at                       ENSMUSG00000032575         74840        NaN
# 1424147_at                       ENSMUSG00000021037        217737        NaN
# 1443934_at                       ENSMUSG00000053070        234912        NaN
# 1434022_at                       ENSMUSG00000048047         56805        NaN
# 1422196_at                       ENSMUSG00000050534         15564        NaN
# 1429746_at                       ENSMUSG00000044056         69306        NaN
# 1421911_at                       ENSMUSG00000040033         20847        NaN
# 1421742_at                                      NaN         14569  Mm.153226
# 1430942_at                                      NaN         71536        NaN
# ...                                             ...           ...        ...
# 1439602_at                       ENSMUSG00000075324           NaN        NaN
# 1431578_at                       ENSMUSG00000022455         74716        NaN
# 1435854_at                       ENSMUSG00000050121        226115        NaN
# 1443183_at                       ENSMUSG00000025261         59026        NaN
# 1436969_at                       ENSMUSG00000042943         71845        NaN
# 1446387_at                                      NaN           NaN        NaN
# 1424562_a_at                     ENSMUSG00000031633         11739        NaN
# 1424251_a_at                     ENSMUSG00000029328         50926        NaN
# 1416621_at                       ENSMUSG00000020536         16897        NaN
# 1431808_a_at                     ENSMUSG00000021922         16427        NaN
# 1456884_at                                      NaN     100038580        NaN
# 1449400_at                       ENSMUSG00000046934         71832        NaN
# 1443599_at                       ENSMUSG00000074467           NaN        NaN
# 1417443_at                       ENSMUSG00000034871        230579        NaN
# 1441883_at                       ENSMUSG00000046727         66060  Mm.272527
# 1445524_at                                      NaN           NaN  Mm.443659
# 1454435_at                                      NaN           NaN        NaN
# 1457736_at                       ENSMUSG00000043614        194309        NaN
# 1450262_at                       ENSMUSG00000040663         56708        NaN
# 1438434_at                       ENSMUSG00000041219        228482        NaN
# 1424355_a_at                     ENSMUSG00000031622         20467        NaN
# 1429286_at                       ENSMUSG00000030048         68888        NaN
# 1438568_at                       ENSMUSG00000048965        244238        NaN
# 1428747_at                       ENSMUSG00000028898         71787        NaN
# 1418052_at                       ENSMUSG00000041939         17855        NaN
# 1434730_at                       ENSMUSG00000097023        101694        NaN
# 1452188_at                       ENSMUSG00000050567        103806        NaN
# 1419072_at                       ENSMUSG00000004035         68312        NaN
# 1449060_at                       ENSMUSG00000028678  631653|73804        NaN
# 1438604_at                       ENSMUSG00000003341         67331        NaN
#
#                                                      GO-Process  \
# Probesets
# 1419807_at                                                  NaN
# 1422287_at                                                  NaN
# 1420418_at                                            transport
# 1460737_at    B cell activation // response to biotic stimul...
# 1453077_a_at  transcription // regulation of transcription, ...
# 1444997_at                                                  NaN
# 1427154_at    keratinization // keratinocyte migration // ke...
# 1437609_at    post-translational protein modification // reg...
# 1422943_a_at             response to stress // response to heat
# 1436737_a_at  focal adhesion formation // insulin receptor s...
# 1423157_at    metabolic process // UDP-N-acetylglucosamine b...
# 1423151_at                 protein folding // mRNA modification
# 1416308_at    metabolic process // oxidation reduction // ga...
# 1437247_at    regulation of transcription, DNA-dependent // ...
# 1448129_at          regulation of actin filament polymerization
# 1451581_at    regulation of phosphoprotein phosphatase activity
# 1417603_at    circadian rhythm // transcription // signal tr...
# 1435250_at                                     snRNA processing
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                                                  NaN
# 1428112_at                                                  NaN
# 1424147_at                response to stress // protein folding
# 1443934_at                                                  NaN
# 1434022_at    transcription // regulation of transcription, ...
# 1422196_at    signal transduction // G-protein coupled recep...
# 1429746_at                                                  NaN
# 1421911_at    transcription // signal transduction // regula...
# 1421742_at    regulation of GTPase activity // small GTPase ...
# 1430942_at                                                  NaN
# ...                                                         ...
# 1439602_at                                                  NaN
# 1431578_at    egg activation // male pronucleus formation //...
# 1435854_at                                                  NaN
# 1443183_at    protein modification process // ubiquitin-depe...
# 1436969_at                                                  NaN
# 1446387_at                                                  NaN
# 1424562_a_at  ADP transport // ATP transport // mitochondria...
# 1424251_a_at  transcription // mRNA metabolic process // reg...
# 1416621_at    maintenance of apical/basal cell polarity // c...
# 1431808_a_at                       hyaluronan metabolic process
# 1456884_at                                                  NaN
# 1449400_at              cellular carbohydrate metabolic process
# 1443599_at                                                  NaN
# 1417443_at                                                  NaN
# 1441883_at                                                  NaN
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at                       transport // protein transport
# 1450262_at    cell surface receptor linked signal transducti...
# 1438434_at                                  signal transduction
# 1424355_a_at  transcription // negative regulation of transc...
# 1429286_at                                                  NaN
# 1438568_at    signal transduction // G-protein coupled recep...
# 1428747_at          translation // selenocysteine incorporation
# 1418052_at    sterol biosynthetic process // steroid biosynt...
# 1434730_at                                                  NaN
# 1452188_at    transcription // Notch signaling pathway // re...
# 1419072_at                                    metabolic process
# 1449060_at                           microtubule-based movement
# 1438604_at    phospholipid transport // ATP biosynthetic pro...
#
#                                                     GO-Function  \
# Probesets
# 1419807_at                                                  NaN
# 1422287_at                                                  NaN
# 1420418_at    calcium ion binding // transporter activity //...
# 1460737_at       protein phosphatase type 2A regulator activity
# 1453077_a_at                                        DNA binding
# 1444997_at                                                  NaN
# 1427154_at      protein binding // structural molecule activity
# 1437609_at            small conjugating protein ligase activity
# 1422943_a_at                                                NaN
# 1436737_a_at  protein binding // insulin receptor binding //...
# 1423157_at    transferase activity // N-acetyltransferase ac...
# 1423151_at    heat shock protein binding // protein binding ...
# 1416308_at    NAD binding // catalytic activity // binding /...
# 1437247_at    transcription factor activity // DNA binding /...
# 1448129_at                                        actin binding
# 1451581_at    protein binding // binding // protein phosphat...
# 1417603_at    two-component sensor activity // protein bindi...
# 1435250_at                                      protein binding
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                                                  NaN
# 1428112_at                               growth factor activity
# 1424147_at    protein binding // ATPase activator activity /...
# 1443934_at                                                  NaN
# 1434022_at    protein binding // DNA binding // metal ion bi...
# 1422196_at    receptor activity // signal transducer activit...
# 1429746_at                                  calcium ion binding
# 1421911_at    calcium ion binding // transcription factor ac...
# 1421742_at    Rab GTPase activator activity // GTPase activa...
# 1430942_at                                                  NaN
# ...                                                         ...
# 1439602_at                                                  NaN
# 1431578_at                 protein binding // WW domain binding
# 1435854_at                                                  NaN
# 1443183_at    ligase activity // DNA binding // binding // u...
# 1436969_at                                                  NaN
# 1446387_at                                                  NaN
# 1424562_a_at  transporter activity // ATP:ADP antiporter act...
# 1424251_a_at  RNA binding // nucleic acid binding // nucleot...
# 1416621_at            protein binding // protein kinase binding
# 1431808_a_at  calcium ion binding // hyaluronic acid binding...
# 1456884_at                                                  NaN
# 1449400_at    citrate (Si)-synthase activity // transferase ...
# 1443599_at                                                  NaN
# 1417443_at                                                  NaN
# 1441883_at                                                  NaN
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at                                                  NaN
# 1450262_at                cytokine activity // receptor binding
# 1438434_at                            GTPase activator activity
# 1424355_a_at  protein binding // transcription corepressor a...
# 1429286_at                                                  NaN
# 1438568_at    receptor activity // signal transducer activit...
# 1428747_at    RNA binding // nucleic acid binding // nucleot...
# 1418052_at    transferase activity // identical protein bind...
# 1434730_at                                                  NaN
# 1452188_at                   transcription coactivator activity
# 1419072_at    transferase activity // glutathione transferas...
# 1449060_at    motor activity // protein binding // nucleotid...
# 1438604_at    ATPase activity, coupled to transmembrane move...
#
#                                                    GO-Component  \
# Probesets
# 1419807_at                                                  NaN
# 1422287_at                                                  NaN
# 1420418_at    synapse // vesicular fraction // cytoplasm // ...
# 1460737_at                                            cytoplasm
# 1453077_a_at                                            nucleus
# 1444997_at                                                  NaN
# 1427154_at            intermediate filament // keratin filament
# 1437609_at                                                  NaN
# 1422943_a_at  intracellular // soluble fraction // contracti...
# 1436737_a_at  cell-cell adherens junction // stress fiber //...
# 1423157_at    endosome // late endosome // ER-Golgi intermed...
# 1423151_at    cytoplasm // endoplasmic reticulum lumen // nu...
# 1416308_at                                                  NaN
# 1437247_at                                              nucleus
# 1448129_at    cytoplasm // cytoskeleton // cell projection /...
# 1451581_at                                            cytoplasm
# 1417603_at                                 cytoplasm // nucleus
# 1435250_at                        integrator complex // nucleus
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                                                  NaN
# 1428112_at                                 extracellular region
# 1424147_at                   cytoplasm // endoplasmic reticulum
# 1443934_at                                                  NaN
# 1434022_at                             intracellular // nucleus
# 1422196_at    plasma membrane // integral to membrane // mem...
# 1429746_at                                                  NaN
# 1421911_at                                 cytoplasm // nucleus
# 1421742_at             cytoplasm // Golgi apparatus // membrane
# 1430942_at                                                  NaN
# ...                                                         ...
# 1439602_at                                                  NaN
# 1431578_at                                    perinuclear theca
# 1435854_at    Golgi apparatus // plasma membrane // integral...
# 1443183_at                cytoplasm // intracellular // nucleus
# 1436969_at                                                  NaN
# 1446387_at                                                  NaN
# 1424562_a_at  mitochondrion // mitochondrial inner membrane ...
# 1424251_a_at                               cytoplasm // nucleus
# 1416621_at    cytoplasm // cytoskeleton // cortical actin cy...
# 1431808_a_at                       cytoplasm // plasma membrane
# 1456884_at                                                  NaN
# 1449400_at                                                  NaN
# 1443599_at                                                  NaN
# 1417443_at                     integral to membrane // membrane
# 1441883_at                                                  NaN
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at                                                  NaN
# 1450262_at          extracellular region // extracellular space
# 1438434_at                                        intracellular
# 1424355_a_at  XY body // Y chromosome // cytoplasm // X chro...
# 1429286_at                                                  NaN
# 1438568_at    plasma membrane // integral to membrane // mem...
# 1428747_at                                 cytoplasm // nucleus
# 1418052_at                              cytoplasm // peroxisome
# 1434730_at                                                  NaN
# 1452188_at                             nucleus // nuclear speck
# 1419072_at                                            cytoplasm
# 1449060_at    microtubule // cytoplasm // nucleus // microtu...
# 1438604_at    integral to membrane of membrane fraction // a...
#
#                                                    Pathway_info  \
# Probesets
# 1419807_at                                                  NaN
# 1422287_at                                                  NaN
# 1420418_at                                                  NaN
# 1460737_at                                                  NaN
# 1453077_a_at                                                NaN
# 1444997_at                                                  NaN
# 1427154_at                                                  NaN
# 1437609_at                                                  NaN
# 1422943_a_at  IL-3 Signaling Pathway:WP373(WikiPathways) // ...
# 1436737_a_at  Insulin Signaling:WP65(WikiPathways) // PPAR s...
# 1423157_at                                                  NaN
# 1423151_at                                                  NaN
# 1416308_at                 Glucuronidation:WP1241(WikiPathways)
# 1437247_at                                                  NaN
# 1448129_at    XPodNet - protein-protein interactions in the ...
# 1451581_at                                                  NaN
# 1417603_at    GenMAPP-Circadian_Exercise // Diurnally Regula...
# 1435250_at                                                  NaN
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                                                  NaN
# 1428112_at                                                  NaN
# 1424147_at                                                  NaN
# 1443934_at                                                  NaN
# 1434022_at    Wnt Signaling Pathway and Pluripotency:WP723(W...
# 1422196_at    GPCRs, Class A Rhodopsin-like:WP189(WikiPathwa...
# 1429746_at                                                  NaN
# 1421911_at    Chemokine signaling pathway:KEGG-mmu04062:WP22...
# 1421742_at                                                  NaN
# 1430942_at                                                  NaN
# ...                                                         ...
# 1439602_at                                                  NaN
# 1431578_at                                                  NaN
# 1435854_at                                                  NaN
# 1443183_at                                                  NaN
# 1436969_at                                                  NaN
# 1446387_at                                                  NaN
# 1424562_a_at  Electron Transport Chain:WP295(WikiPathways) /...
# 1424251_a_at  GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1416621_at                                                  NaN
# 1431808_a_at                                                NaN
# 1456884_at                                                  NaN
# 1449400_at                                                  NaN
# 1443599_at                                                  NaN
# 1417443_at                                                  NaN
# 1441883_at                                                  NaN
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at                                                  NaN
# 1450262_at                                                  NaN
# 1438434_at                                                  NaN
# 1424355_a_at                                                NaN
# 1429286_at                                                  NaN
# 1438568_at                   Odorant GPCRs:WP1397(WikiPathways)
# 1428747_at    Selenium metabolism/Selenoproteins:WP108(WikiP...
# 1418052_at    Cholesterol Biosynthesis:WP103(WikiPathways) /...
# 1434730_at                                                  NaN
# 1452188_at    Delta-Notch Signaling Pathway:WP265(WikiPathwa...
# 1419072_at    Glutathione metabolism:WP164(WikiPathways) // ...
# 1449060_at                                                  NaN
# 1438604_at                                                  NaN
#
#                                 Putative microRNA binding sites  \
# Probesets
# 1419807_at                                                  NaN
# 1422287_at                                                  NaN
# 1420418_at    mmu-let-7(TargetScan), mmu-miR-125a-3p(TargetS...
# 1460737_at    mmu-let-7f(miRanda), mmu-miR-1192(miRanda), mm...
# 1453077_a_at  mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1444997_at                                                  NaN
# 1427154_at    mmu-miR-125a-3p(miRanda), mmu-miR-144(miRanda)...
# 1437609_at    mmu-miR-125a-5p(miRanda), mmu-miR-125b-5p(miRa...
# 1422943_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1436737_a_at  mmu-miR-101a(miRanda), mmu-miR-125a-3p(miRanda...
# 1423157_at    mmu-miR-1(miRanda|pictar), mmu-miR-101a(miRand...
# 1423151_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1416308_at    mmu-let-7d(RNAhybrid|miRanda), mmu-let-7e(RNAh...
# 1437247_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1448129_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1451581_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1417603_at    mmu-miR-1(miRanda), mmu-miR-103(miRanda), mmu-...
# 1435250_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1458261_at                                                  NaN
# 1457883_at                                                  NaN
# 1433191_at                                                  NaN
# 1428112_at    mmu-let-7f(RNAhybrid|miRanda), mmu-miR-106a(mi...
# 1424147_at    mmu-miR-100(RNAhybrid), mmu-miR-125a(RNAhybrid...
# 1443934_at    mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...
# 1434022_at    mmu-let-7i(miRanda), mmu-miR-101(pictar), mmu-...
# 1422196_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1429746_at                                                  NaN
# 1421911_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1421742_at                                                  NaN
# 1430942_at                                                  NaN
# ...                                                         ...
# 1439602_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda), mm...
# 1431578_at    mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
# 1435854_at    mmu-miR-125a-5p(miRanda), mmu-miR-125b-5p(miRa...
# 1443183_at    mmu-let-7e(RNAhybrid|miRanda), mmu-let-7f(RNAh...
# 1436969_at    mmu-miR-106a(miRanda), mmu-miR-130a(miRanda), ...
# 1446387_at                                                  NaN
# 1424562_a_at  mmu-let-7(TargetScan), mmu-let-7a(pictar), mmu...
# 1424251_a_at  mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1416621_at    mmu-let-7b(miRanda), mmu-let-7c(miRanda), mmu-...
# 1431808_a_at  mmu-miR-18a(miRanda), mmu-miR-18b(miRanda), mm...
# 1456884_at                                                  NaN
# 1449400_at                                mmu-miR-1192(miRanda)
# 1443599_at                                                  NaN
# 1417443_at                                                  NaN
# 1441883_at    mmu-miR-122(miRanda), mmu-miR-124a(RNAhybrid|m...
# 1445524_at                                                  NaN
# 1454435_at                                                  NaN
# 1457736_at    mmu-miR-301b(miRanda), mmu-miR-34a(miRanda), m...
# 1450262_at    mmu-miR-1192(TargetScan|miRanda), mmu-miR-122(...
# 1438434_at    mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...
# 1424355_a_at  mmu-miR-1192(miRanda), mmu-miR-125a-3p(miRanda...
# 1429286_at    mmu-let-7a(miRanda), mmu-let-7e(miRanda), mmu-...
# 1438568_at    mmu-miR-124(miRanda), mmu-miR-134(miRanda), mm...
# 1428747_at    mmu-let-7d(RNAhybrid|miRanda), mmu-let-7g(RNAh...
# 1418052_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1434730_at                                                  NaN
# 1452188_at    mmu-miR-103a(TargetScan), mmu-miR-105(TargetSc...
# 1419072_at    mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
# 1449060_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1438604_at    mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
#
#                     ...            ANOVA-adjp largest fold  \
# Probesets           ...
# 1419807_at          ...          4.823408e-01     0.195850
# 1422287_at          ...          8.175388e-01     0.194020
# 1420418_at          ...          1.059304e-02     0.848137
# 1460737_at          ...          2.093642e-01     0.207877
# 1453077_a_at        ...          1.538636e-07     0.829527
# 1444997_at          ...          1.448792e-01     0.434707
# 1427154_at          ...          1.209205e-01     0.305073
# 1437609_at          ...          1.820230e-01     0.315233
# 1422943_a_at        ...          2.403861e-07     1.399137
# 1436737_a_at        ...          2.809740e-05     0.398350
# 1423157_at          ...          5.531520e-01     0.360057
# 1423151_at          ...          1.398274e-06     0.616190
# 1416308_at          ...          1.376288e-11     0.708440
# 1437247_at          ...          9.651444e-11     1.392653
# 1448129_at          ...          2.629690e-06     0.247840
# 1451581_at          ...          6.634008e-01     0.186963
# 1417603_at          ...          2.810215e-04     0.751860
# 1435250_at          ...          9.760189e-07     0.581823
# 1458261_at          ...          5.016313e-01     0.224447
# 1457883_at          ...          4.983983e-01     0.293507
# 1433191_at          ...          3.505042e-01     0.183633
# 1428112_at          ...          1.042066e-12     0.995037
# 1424147_at          ...          1.564675e-09     0.458760
# 1443934_at          ...          4.123664e-08     0.854607
# 1434022_at          ...          4.949280e-02     0.250133
# 1422196_at          ...          2.123965e-02     0.684910
# 1429746_at          ...          8.225586e-01     0.205903
# 1421911_at          ...          1.424132e-02     0.437340
# 1421742_at          ...          1.800033e-01     0.217573
# 1430942_at          ...          1.579648e-02     0.504243
# ...                 ...                   ...          ...
# 1439602_at          ...          8.758306e-01     0.206613
# 1431578_at          ...          4.805173e-01     0.257097
# 1435854_at          ...          5.737906e-10     0.990537
# 1443183_at          ...          1.236840e-01     0.286200
# 1436969_at          ...          2.000062e-01     0.312090
# 1446387_at          ...          2.212263e-01     0.273410
# 1424562_a_at        ...          1.673174e-01     0.118107
# 1424251_a_at        ...          1.488187e-08     0.505213
# 1416621_at          ...          4.709754e-03     0.174990
# 1431808_a_at        ...          3.169999e-01     0.224120
# 1456884_at          ...          1.955314e-04     0.661123
# 1449400_at          ...          3.837382e-01     0.227923
# 1443599_at          ...          4.583375e-01     0.214177
# 1417443_at          ...          2.412846e-02     0.387083
# 1441883_at          ...          2.233777e-01     0.235723
# 1445524_at          ...          4.205499e-01     0.218937
# 1454435_at          ...          5.901508e-01     0.228753
# 1457736_at          ...          1.921838e-04     0.367907
# 1450262_at          ...          1.812607e-01     0.333927
# 1438434_at          ...          2.232196e-01     0.315353
# 1424355_a_at        ...          1.015139e-10     0.546127
# 1429286_at          ...          1.722282e-04     0.790930
# 1438568_at          ...          6.308855e-01     0.171733
# 1428747_at          ...          1.331036e-03     0.408597
# 1418052_at          ...          1.446553e-02     0.278780
# 1434730_at          ...          3.829442e-06     0.624887
# 1452188_at          ...          7.273845e-01     0.190810
# 1419072_at          ...          3.461184e-02     0.284627
# 1449060_at          ...          1.043409e-01     0.383447
# 1438604_at          ...          7.733053e-01     0.217440
#
#               430AV2_ZT6_B6_Enrich  430AV2_ZT6_B6_poolStDev  \
# Probesets
# 1419807_at                0.103112                 0.002307
# 1422287_at                0.127810                 0.003969
# 1420418_at                0.099268                 0.003459
# 1460737_at                0.121710                 0.004475
# 1453077_a_at              0.247660                 0.011456
# 1444997_at                0.211943                 0.011023
# 1427154_at                0.128393                 0.006973
# 1437609_at                0.169615                 0.009275
# 1422943_a_at              0.513740                 0.032523
# 1436737_a_at              0.329637                 0.021541
# 1423157_at                0.309567                 0.020458
# 1423151_at                0.348617                 0.023375
# 1416308_at                0.224205                 0.015454
# 1437247_at                0.605458                 0.042844
# 1448129_at                0.115185                 0.008285
# 1451581_at                0.227935                 0.017131
# 1417603_at                0.356013                 0.027235
# 1435250_at                0.251478                 0.019677
# 1458261_at                0.232880                 0.018877
# 1457883_at                0.210915                 0.017262
# 1433191_at                0.188290                 0.015981
# 1428112_at                0.686232                 0.061406
# 1424147_at                0.225237                 0.020316
# 1443934_at                0.399100                 0.037290
# 1434022_at                0.192290                 0.018395
# 1422196_at                0.448393                 0.042896
# 1429746_at                0.175730                 0.016886
# 1421911_at                0.228677                 0.022033
# 1421742_at                0.187550                 0.018088
# 1430942_at                0.189623                 0.018310
# ...                            ...                      ...
# 1439602_at               -0.052817                 0.005384
# 1431578_at               -0.331630                 0.033702
# 1435854_at               -0.712063                 0.071516
# 1443183_at               -0.205167                 0.019735
# 1436969_at               -0.266905                 0.025662
# 1446387_at               -0.176842                 0.016873
# 1424562_a_at             -0.049222                 0.004638
# 1424251_a_at             -0.216853                 0.020275
# 1416621_at               -0.133258                 0.012352
# 1431808_a_at             -0.222587                 0.020019
# 1456884_at               -0.248757                 0.022066
# 1449400_at               -0.196153                 0.016910
# 1443599_at               -0.225635                 0.019433
# 1417443_at               -0.375795                 0.032297
# 1441883_at               -0.114223                 0.009607
# 1445524_at               -0.211458                 0.017568
# 1454435_at               -0.135123                 0.011051
# 1457736_at               -0.211865                 0.016856
# 1450262_at               -0.115842                 0.009108
# 1438434_at               -0.187862                 0.013802
# 1424355_a_at             -0.283988                 0.020365
# 1429286_at               -0.445058                 0.031901
# 1438568_at               -0.107733                 0.007587
# 1428747_at               -0.290838                 0.020316
# 1418052_at               -0.199865                 0.013739
# 1434730_at               -0.178507                 0.011020
# 1452188_at               -0.191665                 0.009912
# 1419072_at               -0.115097                 0.004201
# 1449060_at               -0.097778                 0.003343
# 1438604_at               -0.195660                 0.006687
#
#               430AV2_ZT6_B6_Cohens_d  430AV2_ZT6_B6_J  430AV2_ZT6_B6_Hedges_g  \
# Probesets
# 1419807_at                 44.699093           0.8125               36.318013
# 1422287_at                 32.202503           0.8125               26.164534
# 1420418_at                 28.697415           0.8125               23.316650
# 1460737_at                 27.198371           0.8125               22.098676
# 1453077_a_at               21.618915           0.8125               17.565369
# 1444997_at                 19.228157           0.8125               15.622878
# 1427154_at                 18.413312           0.8125               14.960816
# 1437609_at                 18.288204           0.8125               14.859166
# 1422943_a_at               15.796378           0.8125               12.834557
# 1436737_a_at               15.302923           0.8125               12.433625
# 1423157_at                 15.131517           0.8125               12.294358
# 1423151_at                 14.914230           0.8125               12.117812
# 1416308_at                 14.507829           0.8125               11.787611
# 1437247_at                 14.131858           0.8125               11.482135
# 1448129_at                 13.903621           0.8125               11.296692
# 1451581_at                 13.305395           0.8125               10.810633
# 1417603_at                 13.072014           0.8125               10.621011
# 1435250_at                 12.780002           0.8125               10.383752
# 1458261_at                 12.336868           0.8125               10.023705
# 1457883_at                 12.218260           0.8125                9.927337
# 1433191_at                 11.781932           0.8125                9.572820
# 1428112_at                 11.175318           0.8125                9.079946
# 1424147_at                 11.086904           0.8125                9.008109
# 1443934_at                 10.702606           0.8125                8.695867
# 1434022_at                 10.453528           0.8125                8.493491
# 1422196_at                 10.453113           0.8125                8.493154
# 1429746_at                 10.406747           0.8125                8.455482
# 1421911_at                 10.378766           0.8125                8.432747
# 1421742_at                 10.368829           0.8125                8.424674
# 1430942_at                 10.356361           0.8125                8.414544
# ...                              ...              ...                     ...
# 1439602_at                 -9.810286           0.8125               -7.970857
# 1431578_at                 -9.840004           0.8125               -7.995003
# 1435854_at                 -9.956769           0.8125               -8.089875
# 1443183_at                -10.395988           0.8125               -8.446740
# 1436969_at                -10.400605           0.8125               -8.450492
# 1446387_at                -10.480995           0.8125               -8.515809
# 1424562_a_at              -10.613236           0.8125               -8.623254
# 1424251_a_at              -10.695353           0.8125               -8.689975
# 1416621_at                -10.788623           0.8125               -8.765756
# 1431808_a_at              -11.118682           0.8125               -9.033929
# 1456884_at                -11.273440           0.8125               -9.159670
# 1449400_at                -11.600026           0.8125               -9.425021
# 1443599_at                -11.611218           0.8125               -9.434115
# 1417443_at                -11.635683           0.8125               -9.453992
# 1441883_at                -11.889304           0.8125               -9.660060
# 1445524_at                -12.036790           0.8125               -9.779892
# 1454435_at                -12.227529           0.8125               -9.934867
# 1457736_at                -12.569448           0.8125              -10.212676
# 1450262_at                -12.718255           0.8125              -10.333582
# 1438434_at                -13.610809           0.8125              -11.058783
# 1424355_a_at              -13.944588           0.8125              -11.329977
# 1429286_at                -13.951204           0.8125              -11.335353
# 1438568_at                -14.198825           0.8125              -11.536545
# 1428747_at                -14.315630           0.8125              -11.631450
# 1418052_at                -14.547630           0.8125              -11.819950
# 1434730_at                -16.197888           0.8125              -13.160784
# 1452188_at                -19.335967           0.8125              -15.710473
# 1419072_at                -27.399292           0.8125              -22.261924
# 1449060_at                -29.249913           0.8125              -23.765555
# 1438604_at                -29.260576           0.8125              -23.774218
#
#               430AV2_ZT6_B6_Var_d  430AV2_ZT6_B6_Var_g  430AV2_ZT6_B6_SEg
# Probesets
# 1419807_at             200.634222           132.449936          11.508690
# 1422287_at             104.533454            69.008413           8.307130
# 1420418_at              83.187498            54.916747           7.410583
# 1460737_at              74.808471            49.385280           7.027466
# 1453077_a_at            47.571083            31.404348           5.603958
# 1444997_at              37.805535            24.957560           4.995754
# 1427154_at              34.738340            22.932733           4.788813
# 1437609_at              34.279174            22.629611           4.757059
# 1422943_a_at            25.785889            17.022716           4.125859
# 1436737_a_at            24.251278            16.009633           4.001204
# 1423157_at              23.729615            15.665254           3.957936
# 1423151_at              23.076760            15.234267           3.903110
# 1416308_at              21.881042            14.444907           3.800646
# 1437247_at              20.804274            13.734072           3.705951
# 1448129_at              20.164400            13.311655           3.648514
# 1451581_at              18.536687            12.237110           3.498158
# 1417603_at              17.921088            11.830718           3.439581
# 1435250_at              17.166179            11.332361           3.366357
# 1458261_at              16.053163            10.597596           3.255395
# 1457883_at              15.761922            10.405331           3.225730
# 1433191_at              14.714726             9.714019           3.116732
# 1428112_at              13.322106             8.794671           2.965581
# 1424147_at              13.125276             8.664733           2.943592
# 1443934_at              12.287911             8.111941           2.848147
# 1434022_at              11.760957             7.764069           2.786408
# 1422196_at              11.760091             7.763498           2.786305
# 1429746_at              11.663372             7.699648           2.774824
# 1421911_at              11.605211             7.661253           2.767897
# 1421742_at              11.584595             7.647643           2.765437
# 1430942_at              11.558755             7.630585           2.762351
# ...                           ...                  ...                ...
# 1439602_at              10.457505             6.903587           2.627468
# 1431578_at              10.515901             6.942138           2.634794
# 1435854_at              10.747058             7.094737           2.663595
# 1443183_at              11.640990             7.684872           2.772160
# 1436969_at              11.650592             7.691211           2.773303
# 1446387_at              11.818460             7.802030           2.793211
# 1424562_a_at            12.097412             7.986182           2.825983
# 1424251_a_at            12.272391             8.101696           2.846348
# 1416621_at              12.472772             8.233978           2.869491
# 1431808_a_at            13.195842             8.711317           2.951494
# 1456884_at              13.542379             8.940086           2.989998
# 1449400_at              14.289395             9.433233           3.071357
# 1443599_at              14.315371             9.450382           3.074147
# 1417443_at              14.372244             9.487927           3.080248
# 1441883_at              14.968889             9.881805           3.143534
# 1445524_at              15.321764            10.114759           3.180371
# 1454435_at              15.784579            10.420289           3.228047
# 1457736_at              16.632435            10.980006           3.313609
# 1450262_at              17.008735            11.228422           3.350884
# 1438434_at              19.358746            12.779797           3.574884
# 1424355_a_at            20.278486            13.386969           3.658821
# 1429286_at              20.296942            13.399153           3.660485
# 1438568_at              20.993996            13.859318           3.722810
# 1428747_at              21.327060            14.079192           3.752225
# 1418052_at              21.996688            14.521251           3.810676
# 1434730_at              27.070490            17.870753           4.227381
# 1452188_at              38.221294            25.232026           5.023149
# 1419072_at              75.905452            50.109458           7.078803
# 1449060_at              86.389077            57.030289           7.551840
# 1438604_at              86.451467            57.071476           7.554567
#
# [40569 rows x 95 columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239868_AK_S_ZT6.CEL',
#        'GSM239869_AK_S_ZT6.CEL', 'GSM239870_AK_S_ZT6.CEL', 'avg-AK_S_ZT6',
#        'log_fold-AK_S_ZT6_vs_AK_SD_ZT6', 'fold-AK_S_ZT6_vs_AK_SD_ZT6',
#        'rawp-AK_S_ZT6_vs_AK_SD_ZT6', 'adjp-AK_S_ZT6_vs_AK_SD_ZT6',
#        'GSM239871_AK_S_ZT12.CEL', 'GSM239872_AK_S_ZT12.CEL',
#        'GSM239873_AK_S_ZT12.CEL', 'avg-AK_S_ZT12',
#        'log_fold-AK_S_ZT12_vs_AK_SD_ZT12', 'fold-AK_S_ZT12_vs_AK_SD_ZT12',
#        'rawp-AK_S_ZT12_vs_AK_SD_ZT12', 'adjp-AK_S_ZT12_vs_AK_SD_ZT12',
#        'GSM239880_AK_SD_ZT6.CEL', 'GSM239881_AK_SD_ZT6.CEL',
#        'GSM239882_AK_SD_ZT6.CEL', 'avg-AK_SD_ZT6', 'GSM239883_AK_SD_ZT12.CEL',
#        'GSM239884_AK_SD_ZT12.CEL', 'GSM239885_AK_SD_ZT12.CEL',
#        'avg-AK_SD_ZT12', 'GSM239891_B6_S_ZT6.CEL',
#        'GSM239892._B6_S_ZT6CEL.CEL', 'GSM239893_B6_S_ZT6.CEL', 'avg-B6_S_ZT6',
#        'log_fold-B6_S_ZT6_vs_B6_SD_ZT6', 'fold-B6_S_ZT6_vs_B6_SD_ZT6',
#        'rawp-B6_S_ZT6_vs_B6_SD_ZT6', 'adjp-B6_S_ZT6_vs_B6_SD_ZT6',
#        'GSM239894_B6_S_ZT12.CEL', 'GSM239895_B6_S_ZT12.CEL',
#        'GSM239896_B6_S_ZT12.CEL', 'avg-B6_S_ZT12',
#        'log_fold-B6_S_ZT12_vs_B6_SD_ZT12', 'fold-B6_S_ZT12_vs_B6_SD_ZT12',
#        'rawp-B6_S_ZT12_vs_B6_SD_ZT12', 'adjp-B6_S_ZT12_vs_B6_SD_ZT12',
#        'GSM239903_B6_SD_ZT6.CEL', 'GSM239904_B6_SD_ZT6.CEL',
#        'GSM239905_B6_SD_ZT6.CEL', 'avg-B6_SD_ZT6', 'GSM239906_B6_SD_ZT12.CEL',
#        'GSM239907._B6_SD_ZT12CEL.CEL', 'GSM239908_B6_SD_ZT12.CEL',
#        'avg-B6_SD_ZT12', 'GSM239915_D2_S_ZT6.CEL', 'GSM239916_D2_S_ZT6.CEL',
#        'GSM239917_D2_S_ZT6.CEL', 'avg-D2_S_ZT6',
#        'log_fold-D2_S_ZT6_vs_D2_SD_ZT6', 'fold-D2_S_ZT6_vs_D2_SD_ZT6',
#        'rawp-D2_S_ZT6_vs_D2_SD_ZT6', 'adjp-D2_S_ZT6_vs_D2_SD_ZT6',
#        'GSM239918_D2_S_ZT12.CEL', 'GSM239919_D2_S_ZT12.CEL',
#        'GSM239920_D2_S_ZT12.CEL', 'avg-D2_S_ZT12',
#        'log_fold-D2_S_ZT12_vs_D2_SD_ZT12', 'fold-D2_S_ZT12_vs_D2_SD_ZT12',
#        'rawp-D2_S_ZT12_vs_D2_SD_ZT12', 'adjp-D2_S_ZT12_vs_D2_SD_ZT12',
#        'GSM239927_D2_SD_ZT6.CEL', 'GSM239928_D2_SD_ZT6.CEL',
#        'GSM239929_D2_SD_ZT6.CEL', 'avg-D2_SD_ZT6', 'GSM239930_D2_SD_ZT12.CEL',
#        'GSM239931_D2_SD_ZT12.CEL', 'GSM239932_D2_SD_ZT12.CEL',
#        'avg-D2_SD_ZT12', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold',
#        '430AV2_ZT6_B6_Enrich', '430AV2_ZT6_B6_poolStDev',
#        '430AV2_ZT6_B6_Cohens_d', '430AV2_ZT6_B6_J', '430AV2_ZT6_B6_Hedges_g',
#        '430AV2_ZT6_B6_Var_d', '430AV2_ZT6_B6_Var_g', '430AV2_ZT6_B6_SEg'],
#       dtype='object')

# %% [markdown]
# ### Import key file from BioMart and index probesets to MGI gene symbols

# %%
dfX=pd.read_table('../FHS project/Sleep notebook Copy/BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[3])
 
dfX.pop('Affy mouse430 2 probeset') # remove 430V2 probeset info (not needed for 430AV2 indexing)
dfX.head(5)
# Out:
#                               Ensembl Gene ID  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ENSMUSG00000039221
# NaN                        ENSMUSG00000095611
# 1417730_at                 ENSMUSG00000061731
# 1417730_at                 ENSMUSG00000061731
# NaN                        ENSMUSG00000061731
#
#                                                                  Description  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                        predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# NaN                        exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                           MGI symbol
# Affy mouse430a 2 probeset
# 1417126_a_at                 Rpl22l1
# NaN                          Gm10597
# 1417730_at                      Ext1
# 1417730_at                      Ext1
# NaN                             Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]   # checking that no duplicate entries exist in the dataframe
# Out:
# Empty DataFrame
# Columns: [GSM239868_AK_S_ZT6.CEL, GSM239869_AK_S_ZT6.CEL, GSM239870_AK_S_ZT6.CEL, avg-AK_S_ZT6, log_fold-AK_S_ZT6_vs_AK_SD_ZT6, fold-AK_S_ZT6_vs_AK_SD_ZT6, rawp-AK_S_ZT6_vs_AK_SD_ZT6, adjp-AK_S_ZT6_vs_AK_SD_ZT6, GSM239871_AK_S_ZT12.CEL, GSM239872_AK_S_ZT12.CEL, GSM239873_AK_S_ZT12.CEL, avg-AK_S_ZT12, log_fold-AK_S_ZT12_vs_AK_SD_ZT12, fold-AK_S_ZT12_vs_AK_SD_ZT12, rawp-AK_S_ZT12_vs_AK_SD_ZT12, adjp-AK_S_ZT12_vs_AK_SD_ZT12, GSM239880_AK_SD_ZT6.CEL, GSM239881_AK_SD_ZT6.CEL, GSM239882_AK_SD_ZT6.CEL, avg-AK_SD_ZT6, GSM239883_AK_SD_ZT12.CEL, GSM239884_AK_SD_ZT12.CEL, GSM239885_AK_SD_ZT12.CEL, avg-AK_SD_ZT12, GSM239891_B6_S_ZT6.CEL, GSM239892._B6_S_ZT6CEL.CEL, GSM239893_B6_S_ZT6.CEL, avg-B6_S_ZT6, log_fold-B6_S_ZT6_vs_B6_SD_ZT6, fold-B6_S_ZT6_vs_B6_SD_ZT6, rawp-B6_S_ZT6_vs_B6_SD_ZT6, adjp-B6_S_ZT6_vs_B6_SD_ZT6, GSM239894_B6_S_ZT12.CEL, GSM239895_B6_S_ZT12.CEL, GSM239896_B6_S_ZT12.CEL, avg-B6_S_ZT12, log_fold-B6_S_ZT12_vs_B6_SD_ZT12, fold-B6_S_ZT12_vs_B6_SD_ZT12, rawp-B6_S_ZT12_vs_B6_SD_ZT12, adjp-B6_S_ZT12_vs_B6_SD_ZT12, GSM239903_B6_SD_ZT6.CEL, GSM239904_B6_SD_ZT6.CEL, GSM239905_B6_SD_ZT6.CEL, avg-B6_SD_ZT6, GSM239906_B6_SD_ZT12.CEL, GSM239907._B6_SD_ZT12CEL.CEL, GSM239908_B6_SD_ZT12.CEL, avg-B6_SD_ZT12, GSM239915_D2_S_ZT6.CEL, GSM239916_D2_S_ZT6.CEL, GSM239917_D2_S_ZT6.CEL, avg-D2_S_ZT6, log_fold-D2_S_ZT6_vs_D2_SD_ZT6, fold-D2_S_ZT6_vs_D2_SD_ZT6, rawp-D2_S_ZT6_vs_D2_SD_ZT6, adjp-D2_S_ZT6_vs_D2_SD_ZT6, GSM239918_D2_S_ZT12.CEL, GSM239919_D2_S_ZT12.CEL, GSM239920_D2_S_ZT12.CEL, avg-D2_S_ZT12, log_fold-D2_S_ZT12_vs_D2_SD_ZT12, fold-D2_S_ZT12_vs_D2_SD_ZT12, rawp-D2_S_ZT12_vs_D2_SD_ZT12, adjp-D2_S_ZT12_vs_D2_SD_ZT12, GSM239927_D2_SD_ZT6.CEL, GSM239928_D2_SD_ZT6.CEL, GSM239929_D2_SD_ZT6.CEL, avg-D2_SD_ZT6, GSM239930_D2_SD_ZT12.CEL, GSM239931_D2_SD_ZT12.CEL, GSM239932_D2_SD_ZT12.CEL, avg-D2_SD_ZT12, ANOVA-rawp, ANOVA-adjp, largest fold, 430AV2_ZT6_B6_Enrich, 430AV2_ZT6_B6_poolStDev, 430AV2_ZT6_B6_Cohens_d, 430AV2_ZT6_B6_J, 430AV2_ZT6_B6_Hedges_g, 430AV2_ZT6_B6_Var_d, 430AV2_ZT6_B6_Var_g, 430AV2_ZT6_B6_SEg]
# Index: []
#
# [0 rows x 83 columns]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average S and SD expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-SD', u'avg-S', u'log_fold-S_vs_SD']]
# df3.columns =[prefix+'avg-SD', prefix+'avg-S', prefix+'log_fold-S_vs_SD']
# df3.to_csv('input_files/430AV2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430AV2_ZT6_B6_Enrich',u'430AV2_ZT6_B6_Hedges_g', u'430AV2_ZT6_B6_Var_g', u'430AV2_ZT6_B6_SEg']]
df4.to_csv('../FHS project/Sleep notebook Copy/IPython_notebooks/input_files/430AV2_ZT6_B6_SymbolforIndexHedges.csv')

# %%
df4.head(10)  # check final ouput
# Out:
#                430AV2_ZT6_B6_Enrich  430AV2_ZT6_B6_Hedges_g  \
# MGI symbol
# 0610005C13Rik              0.150597                1.142943
# 0610008F07Rik              0.114313                0.892054
# 0610009B22Rik              0.062193                0.650009
# 0610009D07Rik             -0.027815               -0.332272
# 0610009O20Rik             -0.106042               -2.276908
# 0610010K14Rik             -0.204008               -1.638292
# 0610012G03Rik              0.034872                0.638659
# 0610031J06Rik             -0.053212               -0.294608
# 0610037L13Rik             -0.061900               -0.456488
# 0610040J01Rik             -0.052467               -0.365625
#
#                430AV2_ZT6_B6_Var_g  430AV2_ZT6_B6_SEg
# MGI symbol
# 0610005C13Rik             0.680762           0.825083
# 0610008F07Rik             0.629706           0.793540
# 0610009B22Rik             0.592381           0.769663
# 0610009D07Rik             0.569284           0.754405
# 0610009O20Rik             1.068561           1.033712
# 0610010K14Rik             0.818530           0.904727
# 0610012G03Rik             0.775008           0.864882
# 0610031J06Rik             0.558810           0.747536
# 0610037L13Rik             0.570968           0.755624
# 0610040J01Rik             0.563498           0.750665
