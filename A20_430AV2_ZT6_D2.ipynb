# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_2}-\bar{X_1}$$
#
# Let Group 1 be 6hSleeping whole brain DBA/2J strain (D2) Expression values and Group 2 be 6hSD whole brain DBA/2J strain (D2) Expression values
#
# (S mean - SD mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviation} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and file IO
import numpy as np # numerical calculations
# %cd /Users/Ella1/Desktop/data sets 430AV2
# Out:
# /Users/Ella1/Desktop/data sets 430AV2

# %%
prefix = '430AV2_ZT6_D2_'   # define a prefix to add to column names (mD2ing indexing easier later)

# %%
# import the data file to a data frame 'df'
df=pd.read_table('DATASET-GSE9442.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.shape
# Out:
# (45101, 87)

# %%
# remove probes that are know to cross-hybridise to more than one target
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (40569, 87)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into S and SD groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239868_AK_S_ZT6.CEL',
#        'GSM239869_AK_S_ZT6.CEL', 'GSM239870_AK_S_ZT6.CEL', 'avg-AK_S_ZT6',
#        'log_fold-AK_S_ZT6_vs_AK_SD_ZT6', 'fold-AK_S_ZT6_vs_AK_SD_ZT6',
#        'rawp-AK_S_ZT6_vs_AK_SD_ZT6', 'adjp-AK_S_ZT6_vs_AK_SD_ZT6',
#        'GSM239871_AK_S_ZT12.CEL', 'GSM239872_AK_S_ZT12.CEL',
#        'GSM239873_AK_S_ZT12.CEL', 'avg-AK_S_ZT12',
#        'log_fold-AK_S_ZT12_vs_AK_SD_ZT12', 'fold-AK_S_ZT12_vs_AK_SD_ZT12',
#        'rawp-AK_S_ZT12_vs_AK_SD_ZT12', 'adjp-AK_S_ZT12_vs_AK_SD_ZT12',
#        'GSM239880_AK_SD_ZT6.CEL', 'GSM239881_AK_SD_ZT6.CEL',
#        'GSM239882_AK_SD_ZT6.CEL', 'avg-AK_SD_ZT6', 'GSM239883_AK_SD_ZT12.CEL',
#        'GSM239884_AK_SD_ZT12.CEL', 'GSM239885_AK_SD_ZT12.CEL',
#        'avg-AK_SD_ZT12', 'GSM239891_B6_S_ZT6.CEL',
#        'GSM239892._B6_S_ZT6CEL.CEL', 'GSM239893_B6_S_ZT6.CEL', 'avg-B6_S_ZT6',
#        'log_fold-B6_S_ZT6_vs_B6_SD_ZT6', 'fold-B6_S_ZT6_vs_B6_SD_ZT6',
#        'rawp-B6_S_ZT6_vs_B6_SD_ZT6', 'adjp-B6_S_ZT6_vs_B6_SD_ZT6',
#        'GSM239894_B6_S_ZT12.CEL', 'GSM239895_B6_S_ZT12.CEL',
#        'GSM239896_B6_S_ZT12.CEL', 'avg-B6_S_ZT12',
#        'log_fold-B6_S_ZT12_vs_B6_SD_ZT12', 'fold-B6_S_ZT12_vs_B6_SD_ZT12',
#        'rawp-B6_S_ZT12_vs_B6_SD_ZT12', 'adjp-B6_S_ZT12_vs_B6_SD_ZT12',
#        'GSM239903_B6_SD_ZT6.CEL', 'GSM239904_B6_SD_ZT6.CEL',
#        'GSM239905_B6_SD_ZT6.CEL', 'avg-B6_SD_ZT6', 'GSM239906_B6_SD_ZT12.CEL',
#        'GSM239907._B6_SD_ZT12CEL.CEL', 'GSM239908_B6_SD_ZT12.CEL',
#        'avg-B6_SD_ZT12', 'GSM239915_D2_S_ZT6.CEL', 'GSM239916_D2_S_ZT6.CEL',
#        'GSM239917_D2_S_ZT6.CEL', 'avg-D2_S_ZT6',
#        'log_fold-D2_S_ZT6_vs_D2_SD_ZT6', 'fold-D2_S_ZT6_vs_D2_SD_ZT6',
#        'rawp-D2_S_ZT6_vs_D2_SD_ZT6', 'adjp-D2_S_ZT6_vs_D2_SD_ZT6',
#        'GSM239918_D2_S_ZT12.CEL', 'GSM239919_D2_S_ZT12.CEL',
#        'GSM239920_D2_S_ZT12.CEL', 'avg-D2_S_ZT12',
#        'log_fold-D2_S_ZT12_vs_D2_SD_ZT12', 'fold-D2_S_ZT12_vs_D2_SD_ZT12',
#        'rawp-D2_S_ZT12_vs_D2_SD_ZT12', 'adjp-D2_S_ZT12_vs_D2_SD_ZT12',
#        'GSM239927_D2_SD_ZT6.CEL', 'GSM239928_D2_SD_ZT6.CEL',
#        'GSM239929_D2_SD_ZT6.CEL', 'avg-D2_SD_ZT6', 'GSM239930_D2_SD_ZT12.CEL',
#        'GSM239931_D2_SD_ZT12.CEL', 'GSM239932_D2_SD_ZT12.CEL',
#        'avg-D2_SD_ZT12', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold'],
#       dtype='object')

# %%
# define regular expressions for sleep (S) and sleep dep (SD) filters 
s_filt ='D2_S_ZT6.CEL'
sd_filt ='D2_SD_ZT6.CEL'

# %%
df_s=df.filter(regex= s_filt)
df_s.head()
# Out:
#               GSM239915_D2_S_ZT6.CEL  GSM239916_D2_S_ZT6.CEL  \
# Probesets
# 1427138_at                   6.01902                 6.09050
# 1425600_a_at                 7.55049                 7.66302
# 1457168_at                   4.71146                 4.67901
# 1450135_at                   4.98641                 5.03533
# 1424014_at                   8.31202                 8.12028
#
#               GSM239917_D2_S_ZT6.CEL
# Probesets
# 1427138_at                   6.15032
# 1425600_a_at                 7.63895
# 1457168_at                   4.60366
# 1450135_at                   4.98962
# 1424014_at                   8.04793

# %%
df_sd=df.filter(regex= sd_filt)
df_sd.head()
# Out:
#               GSM239927_D2_SD_ZT6.CEL  GSM239928_D2_SD_ZT6.CEL  \
# Probesets
# 1427138_at                    6.01677                  6.11602
# 1425600_a_at                  7.48872                  7.48146
# 1457168_at                    4.58878                  4.70513
# 1450135_at                    5.06413                  4.97521
# 1424014_at                    8.23946                  8.18405
#
#               GSM239929_D2_SD_ZT6.CEL
# Probesets
# 1427138_at                    6.20855
# 1425600_a_at                  7.39999
# 1457168_at                    4.49720
# 1450135_at                    5.11886
# 1424014_at                    8.23689

# %% [markdown]
# ## Calculations

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=sd_filt).mean(axis=1) - df.filter(regex=s_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at      0.027167
# 1425600_a_at   -0.160763
# 1457168_at     -0.067673
# 1450135_at      0.048947
# 1424014_at      0.060057
# Name: 430AV2_ZT6_D2_Enrich, dtype: float64

# %%
# Calculating Pooled StDev
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

StdevS = (Scount-1) * df.filter(regex=s_filt).var(axis=1)
StdevSD = (SDcount-1) * df.filter(regex=sd_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevS+StdevSD)/(Scount+ SDcount-2))

# %%
# Calculating Cohen's d
df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
#df[prefix+'poolStDev'].head()
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at      0.330419
# 1425600_a_at   -2.950298
# 1457168_at     -0.811218
# 1450135_at      0.893263
# 1424014_at      0.606635
# Name: 430AV2_ZT6_D2_Cohens_d, dtype: float64

# %%
# Calculating J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(Scount+SDcount-1)))

# %%
# Calculating Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at      0.280856
# 1425600_a_at   -2.507754
# 1457168_at     -0.689535
# 1450135_at      0.759274
# 1424014_at      0.515640
# Name: 430AV2_ZT6_D2_Hedges_g, dtype: float64

# %%
# Calculating Var_d
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

Ftop1 = Scount + SDcount
Ftop2 = Scount * SDcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(Scount + SDcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check output
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.675765
# 1425600_a_at    1.392022
# 1457168_at      0.721506
# 1450135_at      0.733160
# 1424014_at      0.697334
# Name: 430AV2_ZT6_D2_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
# Calculating SEg
df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by= '430AV2_ZT6_D2_Hedges_g', ascending=False, inplace=True)
df
# Out:
#                                                       Symbol  \
# Probesets
# 1445343_at                                             Tmed5
# 1416480_a_at  ENSMUSG00000044330 /// Higd1a /// LOC100045763
# 1439438_a_at                      1110005A23Rik /// EG625193
# 1422676_at                                           Smarce1
# 1428136_at                                             Sfrp1
# 1418350_at                                             Hbegf
# 1428484_at                                            Osbpl3
# 1424244_at                                            Rwdd4a
# 1451822_a_at                                           Scrn2
# 1427835_at                                            Pou2f1
# 1438796_at                                             Nr4a3
# 1451178_at                                Ccdc142 /// Mrpl53
# 1435536_at                                            Rsc1a1
# 1422168_a_at                                            Bdnf
# 1427683_at                                              Egr2
# 1417406_at                                           Sertad1
# 1451981_at                                          Gtrgeo22
# 1427410_at                                             Dleu2
# 1445463_at                                            Npepps
# 1456061_at                                            Gimap8
# 1416455_a_at                                           Cryab
# 1423863_at                                             Abcf2
# 1457589_at                                              Fat3
# 1449564_at                                             Tpsg1
# 1457104_at                                               NaN
# 1448427_at                                            Ndufa6
# 1450949_at                                            Katna1
# 1452215_at                                     9130401M01Rik
# 1418366_at                                        Hist2h2aa1
# 1423006_at                                              Pim1
# ...                                                      ...
# 1450727_a_at                                         Poldip2
# 1440234_at                                     1810012P15Rik
# 1451082_at                                     1300018I05Rik
# 1460208_at                                              Fbn1
# 1434190_at                        OTTMUSG00000017637 /// Sms
# 1454735_at                             LOC100047199 /// Odf2
# 1416822_at                                            Dgcr14
# 1427378_at                                             Krt75
# 1434577_at                         BC052040 /// LOC100048589
# 1446951_at                                             P4ha3
# 1435074_at                                          Tmem106b
# 1424587_at                                            Gemin8
# 1443486_at                                              Cog7
# 1457137_at                                               NaN
# 1450094_at                                           Ranbp17
# 1436182_at                                               NaN
# 1437382_at                                            Acvr2a
# 1426929_at                                           Brunol4
# 1455531_at                                             Mfsd4
# 1452346_at                                            B3gnt1
# 1460565_at                                           Slc41a1
# 1435910_at                                             Fads3
# 1450149_a_at                                          Ppp1cc
# 1431461_at                                     4933417E11Rik
# 1456509_at                                     1110032F04Rik
# 1418383_at                                            Apcdd1
# 1453592_at                                            Lrrc39
# 1443296_at                                             Pctk1
# 1426636_a_at                                            Xiap
# 1452682_at                                           Fam122b
#
#                                                      Definition  \
# Probesets
# 1445343_at    transmembrane emp24 protein transport domain c...
# 1416480_a_at                      HIG1 domain family, member 1A
# 1439438_a_at            SAP domain containing ribonucleoprotein
# 1422676_at    SWI/SNF related, matrix associated, actin depe...
# 1428136_at    secreted frizzled-related protein 1 [Source:MG...
# 1418350_at               heparin-binding EGF-like growth factor
# 1428484_at    oxysterol binding protein-like 3 [Source:MGI S...
# 1424244_at                             RWD domain containing 4A
# 1451822_a_at                                         secernin 2
# 1427835_at          POU domain, class 2, transcription factor 1
# 1438796_at    nuclear receptor subfamily 4, group A, member ...
# 1451178_at                    coiled-coil domain containing 142
# 1435536_at    DNA-damage inducible protein 2 [Source:MGI Sym...
# 1422168_a_at                  brain derived neurotrophic factor
# 1427683_at                              early growth response 2
# 1417406_at                            SERTA domain containing 1
# 1451981_at                              Gene trap ROSA b-geo 22
# 1427410_at                   deleted in lymphocytic leukemia, 2
# 1445463_at    aminopeptidase puromycin sensitive [Source:MGI...
# 1456061_at    GTPase, IMAP family member 8 [Source:MGI Symbo...
# 1416455_a_at                                crystallin, alpha B
# 1423863_at    ATP-binding cassette, sub-family F (GCN20), me...
# 1457589_at    FAT tumor suppressor homolog 3 (Drosophila) [S...
# 1449564_at                                     tryptase gamma 1
# 1457104_at                                                  NaN
# 1448427_at    NADH dehydrogenase (ubiquinone) 1 alpha subcom...
# 1450949_at           katanin p60 (ATPase-containing) subunit A1
# 1452215_at                           RIKEN cDNA 9130401M01 gene
# 1418366_at                             histone cluster 2, H2aa1
# 1423006_at                          proviral integration site 1
# ...                                                         ...
# 1450727_a_at  polymerase (DNA-directed), delta interacting p...
# 1440234_at    LYR motif containing 9 [Source:MGI Symbol;Acc:...
# 1451082_at                                ring finger protein 8
# 1460208_at                                          fibrillin 1
# 1434190_at                                    spermine synthase
# 1454735_at                   outer dense fiber of sperm tails 2
# 1416822_at            DiGeorge syndrome critical region gene 14
# 1427378_at                                           keratin 75
# 1434577_at    cDNA sequence BC052040 [Source:MGI Symbol;Acc:...
# 1446951_at    procollagen-proline, 2-oxoglutarate 4-dioxygen...
# 1435074_at    transmembrane protein 106B [Source:MGI Symbol;...
# 1424587_at         gem (nuclear organelle) associated protein 8
# 1443486_at    component of oligomeric golgi complex 7 [Sourc...
# 1457137_at                                                  NaN
# 1450094_at                               RAN binding protein 17
# 1436182_at           special AT-rich sequence binding protein 1
# 1437382_at                                 activin receptor IIA
# 1426929_at                     CUGBP, Elav-like family member 4
# 1455531_at    major facilitator superfamily domain containing 4
# 1452346_at    UDP-GlcNAc:betaGal beta-1,3-N-acetylglucosamin...
# 1460565_at                   solute carrier family 41, member 1
# 1435910_at    fatty acid desaturase 3 [Source:MGI Symbol;Acc...
# 1450149_a_at  protein phosphatase 1, catalytic subunit, gamm...
# 1431461_at                           RIKEN cDNA 4933417E11 gene
# 1456509_at    RIKEN cDNA 1110032F04 gene [Source:MGI Symbol;...
# 1418383_at         adenomatosis polyposis coli down-regulated 1
# 1453592_at    leucine rich repeat containing 39 [Source:MGI ...
#
#                               Entrez_id Unigene_id  \
# Probesets
# 1445343_at                        73130        NaN
# 1416480_a_at  100045763|56295|100042265        NaN
# 1439438_a_at               625193|66118        NaN
# 1422676_at                        57376        NaN
# 1428136_at                        20377        NaN
# 1418350_at                        15200        NaN
# 1428484_at                        71720        NaN
# 1424244_at                       192174        NaN
# 1451822_a_at                     217140        NaN
# 1427835_at                        18986        NaN
# 1438796_at                        18124        NaN
# 1451178_at                 68499|243510        NaN
# 1435536_at                        69994        NaN
# 1422168_a_at                      12064        NaN
# 1427683_at                        13654        NaN
# 1417406_at                        55942        NaN
# 1451981_at                       110012        NaN
# 1427410_at                668253|328425        NaN
# 1445463_at                        19155        NaN
# 1456061_at                       243374        NaN
# 1416455_a_at                      12955        NaN
# 1423863_at                        27407        NaN
# 1457589_at                       270120        NaN
# 1449564_at                        26945        NaN
# 1457104_at                          NaN  Mm.439250
# 1448427_at                        67130        NaN
# 1450949_at                        23924        NaN
# 1452215_at                        75758        NaN
# 1418366_at          15267|319176|319192        NaN
# 1423006_at                        18712        NaN
# ...                                 ...        ...
# 1450727_a_at                      67811        NaN
# 1440234_at                        66274        NaN
# 1451082_at                  74157|58230        NaN
# 1460208_at                        14118        NaN
# 1434190_at                 20603|671878        NaN
# 1454735_at              18286|100047199        NaN
# 1416822_at                        27886        NaN
# 1427378_at                       109052        NaN
# 1434577_at             100048589|399568        NaN
# 1446951_at                       320452        NaN
# 1435074_at                        71900        NaN
# 1424587_at                       237221        NaN
# 1443486_at                       233824        NaN
# 1457137_at                          NaN  Mm.446668
# 1450094_at                        66011        NaN
# 1436182_at                       |20230        NaN
# 1437382_at                        11480        NaN
# 1426929_at                       108013        NaN
# 1455531_at                       213006        NaN
# 1452346_at                       108902        NaN
# 1460565_at                        98396        NaN
# 1435910_at                        60527        NaN
# 1450149_a_at                      19047        NaN
# 1431461_at                        71134        NaN
# 1456509_at                        68725        NaN
# 1418383_at                       494504        NaN
# 1453592_at                       109245        NaN
# 1443296_at                        18555        NaN
# 1426636_a_at                      11798        NaN
# 1452682_at                        78755        NaN
#
#                                                      GO-Process  \
# Probesets
# 1445343_at                                            transport
# 1416480_a_at                                 response to stress
# 1439438_a_at  transcription // regulation of transcription, ...
# 1422676_at                               chromatin modification
# 1428136_at    anterior/posterior pattern formation // multic...
# 1418350_at    regulation of heart contraction // positive re...
# 1428484_at    lipid transport // steroid metabolic process /...
# 1424244_at                                                  NaN
# 1451822_a_at                                        proteolysis
# 1427835_at    olfactory placode formation // regulation of t...
# 1438796_at    adult behavior // positive regulation of trans...
# 1451178_at                                                  NaN
# 1435536_at    transcription // intestinal absorption // nega...
# 1422168_a_at  feeding behavior // positive regulation of neu...
# 1427683_at    brain segmentation // myelination // facial ne...
# 1417406_at    transcription // positive regulation of transc...
# 1451981_at    sperm axoneme assembly // adult behavior // sp...
# 1427410_at                                                  NaN
# 1445463_at                                          proteolysis
# 1456061_at                                                  NaN
# 1416455_a_at  camera-type eye development // response to hea...
# 1423863_at                                                  NaN
# 1457589_at    cell adhesion // multicellular organismal deve...
# 1449564_at                                          proteolysis
# 1457104_at                                                  NaN
# 1448427_at    electron transport chain // response to oxidat...
# 1450949_at    protein localization // cytoplasmic microtubul...
# 1452215_at                                                  NaN
# 1418366_at                                                  NaN
# 1423006_at    cell proliferation // protein amino acid phosp...
# ...                                                         ...
# 1450727_a_at                                                NaN
# 1440234_at                                                  NaN
# 1451082_at    cell division // mitosis // cell cycle // resp...
# 1460208_at    skeletal system development // chitin metaboli...
# 1434190_at    spermine biosynthetic process // spermine meta...
# 1454735_at    spermatogenesis // multicellular organismal de...
# 1416822_at    mRNA processing // RNA splicing // nervous sys...
# 1427378_at                                                  NaN
# 1434577_at                                                  NaN
# 1446951_at     oxidation reduction // protein metabolic process
# 1435074_at                                                  NaN
# 1424587_at    RNA splicing // mRNA processing // spliceosoma...
# 1443486_at    retrograde vesicle-mediated transport, Golgi t...
# 1457137_at                                                  NaN
# 1450094_at    intracellular protein transmembrane transport ...
# 1436182_at                                                  NaN
# 1437382_at    male gonad development // mesoderm development...
# 1426929_at        mRNA splice site selection // mRNA processing
# 1455531_at                                            transport
# 1452346_at                                                  NaN
# 1460565_at       ion transport // cation transport // transport
# 1435910_at    electron transport chain // oxidation reductio...
# 1450149_a_at  cell division // protein amino acid dephosphor...
# 1431461_at                                                  NaN
# 1456509_at                                                  NaN
# 1418383_at                                                  NaN
# 1453592_at                                                  NaN
# 1443296_at                   protein amino acid phosphorylation
# 1426636_a_at  negative regulation of caspase activity // apo...
# 1452682_at                                                  NaN
#
#                                                     GO-Function  \
# Probesets
# 1445343_at                                                  NaN
# 1416480_a_at                                                NaN
# 1439438_a_at  nucleic acid binding // protein binding // DNA...
# 1422676_at                                          DNA binding
# 1428136_at                                      protein binding
# 1418350_at    epidermal growth factor receptor binding // gr...
# 1428484_at                                                  NaN
# 1424244_at                                                  NaN
# 1451822_a_at                               dipeptidase activity
# 1427835_at    transcription factor activity // protein bindi...
# 1438796_at    transcription factor activity // ligand-depend...
# 1451178_at                                                  NaN
# 1435536_at                                      protein binding
# 1422168_a_at  protein binding // growth factor activity // r...
# 1427683_at    nucleic acid binding // transcription factor a...
# 1417406_at    protein binding // transcription activator act...
# 1451981_at                                                  NaN
# 1427410_at                                                  NaN
# 1445463_at    aminopeptidase activity // peptidase activity ...
# 1456061_at                    nucleotide binding // GTP binding
# 1416455_a_at                 structural constituent of eye lens
# 1423863_at    nucleoside-triphosphatase activity // nucleoti...
# 1457589_at               calcium ion binding // protein binding
# 1449564_at    peptidase activity // catalytic activity // hy...
# 1457104_at                                                  NaN
# 1448427_at                                                  NaN
# 1450949_at    dynein binding // hydrolase activity // protei...
# 1452215_at                                              binding
# 1418366_at                                                  NaN
# 1423006_at    protein binding // manganese ion binding // pr...
# ...                                                         ...
# 1450727_a_at                          protein binding, bridging
# 1440234_at                                                  NaN
# 1451082_at    nucleic acid binding // acid-amino acid ligase...
# 1460208_at    calcium ion binding // protein binding // bind...
# 1434190_at    catalytic activity // spermine synthase activi...
# 1454735_at               structural constituent of cytoskeleton
# 1416822_at                                                  NaN
# 1427378_at                         structural molecule activity
# 1434577_at                                      protein binding
# 1446951_at    oxidoreductase activity, acting on single dono...
# 1435074_at                                                  NaN
# 1424587_at                                      protein binding
# 1443486_at                                      protein binding
# 1457137_at                                                  NaN
# 1450094_at    binding // Ran GTPase binding // protein trans...
# 1436182_at                                                  NaN
# 1437382_at    receptor activity // nucleotide binding // mag...
# 1426929_at    RNA binding // nucleic acid binding // nucleot...
# 1455531_at                                 transporter activity
# 1452346_at    N-acetyllactosaminide beta-1,3-N-acetylglucosa...
# 1460565_at    cation transmembrane transporter activity // m...
# 1435910_at    heme binding // transition metal ion binding /...
# 1450149_a_at  protein serine/threonine phosphatase activity ...
# 1431461_at                                                  NaN
# 1456509_at                                                  NaN
# 1418383_at                                                  NaN
# 1453592_at                                      protein binding
# 1443296_at    cyclin-dependent protein kinase activity // pr...
# 1426636_a_at  protein binding // ligase activity // metal io...
# 1452682_at                                                  NaN
#
#                                                    GO-Component  \
# Probesets
# 1445343_at    endoplasmic reticulum membrane // endoplasmic ...
# 1416480_a_at                   integral to membrane // membrane
# 1439438_a_at                                            nucleus
# 1422676_at                                              nucleus
# 1428136_at                                 extracellular region
# 1418350_at    extracellular space // extracellular region //...
# 1428484_at                                                  NaN
# 1424244_at                                                  NaN
# 1451822_a_at                                                NaN
# 1427835_at              transcription factor complex // nucleus
# 1438796_at                                              nucleus
# 1451178_at    mitochondrion // ribosome // ribonucleoprotein...
# 1435536_at    Golgi apparatus // brush border // membrane fr...
# 1422168_a_at  extracellular region // endoplasmic reticulum ...
# 1427683_at                             intracellular // nucleus
# 1417406_at                                 cytoplasm // nucleus
# 1451981_at    flagellum // microtubule // cytoplasm // centr...
# 1427410_at                                                  NaN
# 1445463_at                                 cytoplasm // nucleus
# 1456061_at    mitochondrion // endoplasmic reticulum // Golg...
# 1416455_a_at  insoluble fraction // soluble fraction // cont...
# 1423863_at                                                  NaN
# 1457589_at                     integral to membrane // membrane
# 1449564_at                     integral to membrane // membrane
# 1457104_at                                                  NaN
# 1448427_at    mitochondrion // mitochondrial inner membrane ...
# 1450949_at    lipid particle // microtubule // cytoplasm // ...
# 1452215_at                                                  NaN
# 1418366_at                                                  NaN
# 1423006_at                                 cytoplasm // nucleus
# ...                                                         ...
# 1450727_a_at                           mitochondrion // nucleus
# 1440234_at                                                  NaN
# 1451082_at                             intracellular // nucleus
# 1460208_at    extracellular space // microfibril // extracel...
# 1434190_at                                                  NaN
# 1454735_at    flagellum // microtubule // centrosome // cent...
# 1416822_at                               spliceosome // nucleus
# 1427378_at            intermediate filament // keratin filament
# 1434577_at                                                  NaN
# 1446951_at    endoplasmic reticulum lumen // endoplasmic ret...
# 1435074_at                     integral to membrane // membrane
# 1424587_at    spliceosome // cytoplasm // nucleus // SMN com...
# 1443486_at    Golgi transport complex // Golgi membrane // G...
# 1457137_at                                                  NaN
# 1450094_at                 cytoplasm // nucleus // nuclear pore
# 1436182_at                                                  NaN
# 1437382_at        cytoplasm // integral to membrane // membrane
# 1426929_at                                 cytoplasm // nucleus
# 1455531_at                     integral to membrane // membrane
# 1452346_at    Golgi membrane // Golgi apparatus // integral ...
# 1460565_at                     integral to membrane // membrane
# 1435910_at    endoplasmic reticulum membrane // endoplasmic ...
# 1450149_a_at  mitochondrion // cytoplasm // mitochondrial ou...
# 1431461_at                                                  NaN
# 1456509_at                                                  NaN
# 1418383_at                     integral to membrane // membrane
# 1453592_at                                                  NaN
# 1443296_at                                                  NaN
# 1426636_a_at                         cytoplasm // intracellular
# 1452682_at                                                  NaN
#
#                                                    Pathway_info  \
# Probesets
# 1445343_at                                                  NaN
# 1416480_a_at                                                NaN
# 1439438_a_at                                                NaN
# 1422676_at    TNF-alpha NF-kB Signaling Pathway:WP246(WikiPa...
# 1428136_at    BMP Signaling Pathway in Eyelid Development:WP...
# 1418350_at    ErbB signaling pathway:WP1261(WikiPathways) //...
# 1428484_at                                                  NaN
# 1424244_at                                                  NaN
# 1451822_a_at                                                NaN
# 1427835_at    PluriNetWork:WP1763(WikiPathways) // Selenium ...
# 1438796_at    XPodNet - protein-protein interactions in the ...
# 1451178_at                                                  NaN
# 1435536_at                                                  NaN
# 1422168_a_at  Spinal Cord Injury:WP2432(WikiPathways) // MAP...
# 1427683_at    Adipogenesis genes:WP447(WikiPathways) // Whit...
# 1417406_at                                                  NaN
# 1451981_at                                                  NaN
# 1427410_at                                                  NaN
# 1445463_at    Orphan GPCRs:WP1398(WikiPathways) // Odorant G...
# 1456061_at                                                  NaN
# 1416455_a_at                                                NaN
# 1423863_at                                                  NaN
# 1457589_at                                                  NaN
# 1449564_at                                                  NaN
# 1457104_at                                                  NaN
# 1448427_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1450949_at                                                  NaN
# 1452215_at                                                  NaN
# 1418366_at                                                  NaN
# 1423006_at    PluriNetWork:WP1763(WikiPathways) // IL-5 Sign...
# ...                                                         ...
# 1450727_a_at                                                NaN
# 1440234_at                                                  NaN
# 1451082_at                                                  NaN
# 1460208_at                                                  NaN
# 1434190_at                                                  NaN
# 1454735_at                                                  NaN
# 1416822_at                                                  NaN
# 1427378_at                                                  NaN
# 1434577_at                                                  NaN
# 1446951_at                                                  NaN
# 1435074_at                                                  NaN
# 1424587_at                                                  NaN
# 1443486_at                                                  NaN
# 1457137_at                                                  NaN
# 1450094_at                                                  NaN
# 1436182_at                    PluriNetWork:WP1763(WikiPathways)
# 1437382_at    miR-127 in mesendoderm differentiation:WP3991(...
# 1426929_at                  mRNA processing:WP310(WikiPathways)
# 1455531_at                                                  NaN
# 1452346_at                                                  NaN
# 1460565_at                                                  NaN
# 1435910_at                                                  NaN
# 1450149_a_at               Insulin Signaling:WP65(WikiPathways)
# 1431461_at                                                  NaN
# 1456509_at                                                  NaN
# 1418383_at                                                  NaN
# 1453592_at                                                  NaN
# 1443296_at                                                  NaN
# 1426636_a_at  Apoptosis:WP1254(WikiPathways) // GenMAPP-Apop...
# 1452682_at                                                  NaN
#
#                                 Putative microRNA binding sites  \
# Probesets
# 1445343_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda|pict...
# 1416480_a_at  mmu-miR-103(pictar), mmu-miR-107(pictar), mmu-...
# 1439438_a_at                                                NaN
# 1422676_at    mmu-miR-103a(TargetScan), mmu-miR-107(TargetSc...
# 1428136_at    mmu-miR-1(miRanda|pictar), mmu-miR-124(miRanda...
# 1418350_at    mmu-let-7c(miRanda), mmu-miR-1192(TargetScan|m...
# 1428484_at    mmu-let-7(TargetScan), mmu-let-7a(pictar), mmu...
# 1424244_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1451822_a_at  mmu-miR-224(miRanda), mmu-miR-490(miRanda), mm...
# 1427835_at                                                  NaN
# 1438796_at    mmu-let-7b(miRanda), mmu-let-7e(miRanda), mmu-...
# 1451178_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1435536_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda), mm...
# 1422168_a_at  mmu-miR-1(miRanda|pictar), mmu-miR-103(miRanda...
# 1427683_at    mmu-let-7g(RNAhybrid|miRanda), mmu-miR-100(RNA...
# 1417406_at    mmu-miR-138(miRanda), mmu-miR-149(miRanda), mm...
# 1451981_at    mmu-miR-10b(miRanda), mmu-miR-299(miRanda), mm...
# 1427410_at                                                  NaN
# 1445463_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1456061_at    mmu-miR-1192(miRanda), mmu-miR-139-5p(miRanda)...
# 1416455_a_at  mmu-miR-101b(RNAhybrid|miRanda), mmu-miR-103(R...
# 1423863_at    mmu-let-7d(RNAhybrid|miRanda), mmu-let-7e(RNAh...
# 1457589_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1449564_at        mmu-miR-296-3p(miRanda), mmu-miR-320(miRanda)
# 1457104_at                                                  NaN
# 1448427_at    mmu-miR-125a-3p(miRanda), mmu-miR-181a(RNAhybr...
# 1450949_at    mmu-let-7g(RNAhybrid|miRanda), mmu-miR-100(miR...
# 1452215_at    mmu-miR-185(miRanda), mmu-miR-186(miRanda), mm...
# 1418366_at                                                  NaN
# 1423006_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# ...                                                         ...
# 1450727_a_at  mmu-miR-101b(miRanda), mmu-miR-103a(TargetScan...
# 1440234_at                                                  NaN
# 1451082_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda), mm...
# 1460208_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1434190_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1454735_at    mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1416822_at    mmu-let-7a(RNAhybrid), mmu-let-7b(RNAhybrid|mi...
# 1427378_at    mmu-miR-129-5p(miRanda), mmu-miR-138(miRanda),...
# 1434577_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1446951_at    mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1435074_at    mmu-let-7e(RNAhybrid|miRanda), mmu-miR-1(miRan...
# 1424587_at    mmu-miR-1(miRanda), mmu-miR-128(miRanda), mmu-...
# 1443486_at    mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
# 1457137_at                                                  NaN
# 1450094_at    mmu-miR-1(miRanda), mmu-miR-106a(miRanda), mmu...
# 1436182_at    mmu-miR-103(RNAhybrid), mmu-miR-106a(RNAhybrid...
# 1437382_at    mmu-let-7(TargetScan), mmu-miR-103(pictar), mm...
# 1426929_at    mmu-let-7a(RNAhybrid|TargetScan|miRanda), mmu-...
# 1455531_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda), mm...
# 1452346_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda), mm...
# 1460565_at    mmu-let-7b(miRanda), mmu-miR-106a(miRanda), mm...
# 1435910_at    mmu-miR-135a(miRanda), mmu-miR-135b(miRanda), ...
# 1450149_a_at  mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...
# 1431461_at                                                  NaN
# 1456509_at                                                  NaN
# 1418383_at    mmu-miR-106a(miRanda), mmu-miR-106ab(TargetSca...
# 1453592_at    mmu-miR-1(miRanda), mmu-miR-101a(miRanda), mmu...
# 1443296_at    mmu-miR-101a(RNAhybrid|miRanda), mmu-miR-101b(...
# 1426636_a_at  mmu-miR-1(miRanda), mmu-miR-106ab(TargetScan),...
# 1452682_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
#
#                     ...            ANOVA-adjp largest fold  \
# Probesets           ...
# 1445343_at          ...          4.759563e-05     0.289457
# 1416480_a_at        ...          2.262908e-04     0.354053
# 1439438_a_at        ...          3.069488e-04     0.257413
# 1422676_at          ...          2.976215e-07     0.481577
# 1428136_at          ...          6.246915e-01     0.328150
# 1418350_at          ...          7.551282e-04     0.433440
# 1428484_at          ...          5.428254e-07     0.632187
# 1424244_at          ...          1.768311e-01     0.264650
# 1451822_a_at        ...          1.604936e-03     0.395303
# 1427835_at          ...          1.273483e-01     0.286257
# 1438796_at          ...          2.483710e-09     1.065537
# 1451178_at          ...          6.058008e-03     0.327960
# 1435536_at          ...          5.679223e-08     0.575027
# 1422168_a_at        ...          1.586481e-10     1.250987
# 1427683_at          ...          5.582401e-08     2.112627
# 1417406_at          ...          9.282709e-06     0.496047
# 1451981_at          ...          4.981911e-01     0.340790
# 1427410_at          ...          1.013767e-10     1.106117
# 1445463_at          ...          5.381135e-02     0.314420
# 1456061_at          ...          8.932249e-05     0.831743
# 1416455_a_at        ...          6.945601e-08     0.843033
# 1423863_at          ...          3.211804e-01     0.260207
# 1457589_at          ...          7.119525e-03     0.223497
# 1449564_at          ...          1.214036e-02     0.333723
# 1457104_at          ...          5.809104e-02     0.280517
# 1448427_at          ...          2.240458e-01     0.176443
# 1450949_at          ...          3.120100e-07     0.559997
# 1452215_at          ...          3.015254e-04     0.378037
# 1418366_at          ...          2.692462e-01     0.362890
# 1423006_at          ...          1.830156e-02     0.330220
# ...                 ...                   ...          ...
# 1450727_a_at        ...          1.816010e-01     0.274567
# 1440234_at          ...          1.897839e-03     0.364717
# 1451082_at          ...          7.975560e-04     0.393693
# 1460208_at          ...          4.236664e-06     0.589170
# 1434190_at          ...          2.398428e-01     0.170837
# 1454735_at          ...          1.940305e-03     0.209707
# 1416822_at          ...          3.464306e-01     0.296317
# 1427378_at          ...          4.436009e-02     0.433790
# 1434577_at          ...          2.134349e-01     0.333070
# 1446951_at          ...          6.691107e-06     0.632170
# 1435074_at          ...          2.514102e-02     0.197987
# 1424587_at          ...          2.115555e-02     0.407507
# 1443486_at          ...          1.646979e-01     0.314310
# 1457137_at          ...          1.194491e-06     0.968253
# 1450094_at          ...          1.747501e-01     0.329697
# 1436182_at          ...          1.073921e-02     0.302687
# 1437382_at          ...          9.970580e-02     0.311190
columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239868_AK_S_ZT6.CEL',
#        'GSM239869_AK_S_ZT6.CEL', 'GSM239870_AK_S_ZT6.CEL', 'avg-AK_S_ZT6',
#        'log_fold-AK_S_ZT6_vs_AK_SD_ZT6', 'fold-AK_S_ZT6_vs_AK_SD_ZT6',
#        'rawp-AK_S_ZT6_vs_AK_SD_ZT6', 'adjp-AK_S_ZT6_vs_AK_SD_ZT6',
#        'GSM239871_AK_S_ZT12.CEL', 'GSM239872_AK_S_ZT12.CEL',
#        'GSM239873_AK_S_ZT12.CEL', 'avg-AK_S_ZT12',
#        'log_fold-AK_S_ZT12_vs_AK_SD_ZT12', 'fold-AK_S_ZT12_vs_AK_SD_ZT12',
#        'rawp-AK_S_ZT12_vs_AK_SD_ZT12', 'adjp-AK_S_ZT12_vs_AK_SD_ZT12',
#        'GSM239880_AK_SD_ZT6.CEL', 'GSM239881_AK_SD_ZT6.CEL',
#        'GSM239882_AK_SD_ZT6.CEL', 'avg-AK_SD_ZT6', 'GSM239883_AK_SD_ZT12.CEL',
#        'GSM239884_AK_SD_ZT12.CEL', 'GSM239885_AK_SD_ZT12.CEL',
#        'avg-AK_SD_ZT12', 'GSM239891_B6_S_ZT6.CEL',
#        'GSM239892._B6_S_ZT6CEL.CEL', 'GSM239893_B6_S_ZT6.CEL', 'avg-B6_S_ZT6',
#        'log_fold-B6_S_ZT6_vs_B6_SD_ZT6', 'fold-B6_S_ZT6_vs_B6_SD_ZT6',
#        'rawp-B6_S_ZT6_vs_B6_SD_ZT6', 'adjp-B6_S_ZT6_vs_B6_SD_ZT6',
#        'GSM239894_B6_S_ZT12.CEL', 'GSM239895_B6_S_ZT12.CEL',
#        'GSM239896_B6_S_ZT12.CEL', 'avg-B6_S_ZT12',
#        'log_fold-B6_S_ZT12_vs_B6_SD_ZT12', 'fold-B6_S_ZT12_vs_B6_SD_ZT12',
#        'rawp-B6_S_ZT12_vs_B6_SD_ZT12', 'adjp-B6_S_ZT12_vs_B6_SD_ZT12',
#        'GSM239903_B6_SD_ZT6.CEL', 'GSM239904_B6_SD_ZT6.CEL',
#        'GSM239905_B6_SD_ZT6.CEL', 'avg-B6_SD_ZT6', 'GSM239906_B6_SD_ZT12.CEL',
#        'GSM239907._B6_SD_ZT12CEL.CEL', 'GSM239908_B6_SD_ZT12.CEL',
#        'avg-B6_SD_ZT12', 'GSM239915_D2_S_ZT6.CEL', 'GSM239916_D2_S_ZT6.CEL',
#        'GSM239917_D2_S_ZT6.CEL', 'avg-D2_S_ZT6',
#        'log_fold-D2_S_ZT6_vs_D2_SD_ZT6', 'fold-D2_S_ZT6_vs_D2_SD_ZT6',
#        'rawp-D2_S_ZT6_vs_D2_SD_ZT6', 'adjp-D2_S_ZT6_vs_D2_SD_ZT6',
#        'GSM239918_D2_S_ZT12.CEL', 'GSM239919_D2_S_ZT12.CEL',
#        'GSM239920_D2_S_ZT12.CEL', 'avg-D2_S_ZT12',
#        'log_fold-D2_S_ZT12_vs_D2_SD_ZT12', 'fold-D2_S_ZT12_vs_D2_SD_ZT12',
#        'rawp-D2_S_ZT12_vs_D2_SD_ZT12', 'adjp-D2_S_ZT12_vs_D2_SD_ZT12',
#        'GSM239927_D2_SD_ZT6.CEL', 'GSM239928_D2_SD_ZT6.CEL',
#        'GSM239929_D2_SD_ZT6.CEL', 'avg-D2_SD_ZT6', 'GSM239930_D2_SD_ZT12.CEL',
#        'GSM239931_D2_SD_ZT12.CEL', 'GSM239932_D2_SD_ZT12.CEL',
#        'avg-D2_SD_ZT12', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold',
#        '430AV2_ZT6_D2_Enrich', '430AV2_ZT6_D2_poolStDev',
#        '430AV2_ZT6_D2_Cohens_d', '430AV2_ZT6_D2_J', '430AV2_ZT6_D2_Hedges_g',
#        '430AV2_ZT6_D2_Var_d', '430AV2_ZT6_D2_Var_g', '430AV2_ZT6_D2_SEg'],
#       dtype='object')

# %% [markdown]
# ### Import key file from BioMart and index probesets to MGI gene symbols

# %%
dfX=pd.read_table('../FHS project/Sleep notebook Copy/BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[3])
 
dfX.pop('Affy mouse430 2 probeset') # remove 430V2 probeset info (not needed for 430AV2 indexing)
dfX.head(5)
# Out:
#                               Ensembl Gene ID  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ENSMUSG00000039221
# NaN                        ENSMUSG00000095611
# 1417730_at                 ENSMUSG00000061731
# 1417730_at                 ENSMUSG00000061731
# NaN                        ENSMUSG00000061731
#
#                                                                  Description  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                        predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# NaN                        exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                           MGI symbol
# Affy mouse430a 2 probeset
# 1417126_a_at                 Rpl22l1
# NaN                          Gm10597
# 1417730_at                      Ext1
# 1417730_at                      Ext1
# NaN                             Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]   # checking that no duplicate entries exist in the dataframe
# Out:
# Empty DataFrame
# Columns: [GSM239868_AK_S_ZT6.CEL, GSM239869_AK_S_ZT6.CEL, GSM239870_AK_S_ZT6.CEL, avg-AK_S_ZT6, log_fold-AK_S_ZT6_vs_AK_SD_ZT6, fold-AK_S_ZT6_vs_AK_SD_ZT6, rawp-AK_S_ZT6_vs_AK_SD_ZT6, adjp-AK_S_ZT6_vs_AK_SD_ZT6, GSM239871_AK_S_ZT12.CEL, GSM239872_AK_S_ZT12.CEL, GSM239873_AK_S_ZT12.CEL, avg-AK_S_ZT12, log_fold-AK_S_ZT12_vs_AK_SD_ZT12, fold-AK_S_ZT12_vs_AK_SD_ZT12, rawp-AK_S_ZT12_vs_AK_SD_ZT12, adjp-AK_S_ZT12_vs_AK_SD_ZT12, GSM239880_AK_SD_ZT6.CEL, GSM239881_AK_SD_ZT6.CEL, GSM239882_AK_SD_ZT6.CEL, avg-AK_SD_ZT6, GSM239883_AK_SD_ZT12.CEL, GSM239884_AK_SD_ZT12.CEL, GSM239885_AK_SD_ZT12.CEL, avg-AK_SD_ZT12, GSM239891_B6_S_ZT6.CEL, GSM239892._B6_S_ZT6CEL.CEL, GSM239893_B6_S_ZT6.CEL, avg-B6_S_ZT6, log_fold-B6_S_ZT6_vs_B6_SD_ZT6, fold-B6_S_ZT6_vs_B6_SD_ZT6, rawp-B6_S_ZT6_vs_B6_SD_ZT6, adjp-B6_S_ZT6_vs_B6_SD_ZT6, GSM239894_B6_S_ZT12.CEL, GSM239895_B6_S_ZT12.CEL, GSM239896_B6_S_ZT12.CEL, avg-B6_S_ZT12, log_fold-B6_S_ZT12_vs_B6_SD_ZT12, fold-B6_S_ZT12_vs_B6_SD_ZT12, rawp-B6_S_ZT12_vs_B6_SD_ZT12, adjp-B6_S_ZT12_vs_B6_SD_ZT12, GSM239903_B6_SD_ZT6.CEL, GSM239904_B6_SD_ZT6.CEL, GSM239905_B6_SD_ZT6.CEL, avg-B6_SD_ZT6, GSM239906_B6_SD_ZT12.CEL, GSM239907._B6_SD_ZT12CEL.CEL, GSM239908_B6_SD_ZT12.CEL, avg-B6_SD_ZT12, GSM239915_D2_S_ZT6.CEL, GSM239916_D2_S_ZT6.CEL, GSM239917_D2_S_ZT6.CEL, avg-D2_S_ZT6, log_fold-D2_S_ZT6_vs_D2_SD_ZT6, fold-D2_S_ZT6_vs_D2_SD_ZT6, rawp-D2_S_ZT6_vs_D2_SD_ZT6, adjp-D2_S_ZT6_vs_D2_SD_ZT6, GSM239918_D2_S_ZT12.CEL, GSM239919_D2_S_ZT12.CEL, GSM239920_D2_S_ZT12.CEL, avg-D2_S_ZT12, log_fold-D2_S_ZT12_vs_D2_SD_ZT12, fold-D2_S_ZT12_vs_D2_SD_ZT12, rawp-D2_S_ZT12_vs_D2_SD_ZT12, adjp-D2_S_ZT12_vs_D2_SD_ZT12, GSM239927_D2_SD_ZT6.CEL, GSM239928_D2_SD_ZT6.CEL, GSM239929_D2_SD_ZT6.CEL, avg-D2_SD_ZT6, GSM239930_D2_SD_ZT12.CEL, GSM239931_D2_SD_ZT12.CEL, GSM239932_D2_SD_ZT12.CEL, avg-D2_SD_ZT12, ANOVA-rawp, ANOVA-adjp, largest fold, 430AV2_ZT6_D2_Enrich, 430AV2_ZT6_D2_poolStDev, 430AV2_ZT6_D2_Cohens_d, 430AV2_ZT6_D2_J, 430AV2_ZT6_D2_Hedges_g, 430AV2_ZT6_D2_Var_d, 430AV2_ZT6_D2_Var_g, 430AV2_ZT6_D2_SEg]
# Index: []
#
# [0 rows x 83 columns]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average S and SD expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-SD', u'avg-S', u'log_fold-S_vs_SD']]
# df3.columns =[prefix+'avg-SD', prefix+'avg-S', prefix+'log_fold-S_vs_SD']
# df3.to_csv('input_files/430AV2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430AV2_ZT6_D2_Enrich',u'430AV2_ZT6_D2_Hedges_g', u'430AV2_ZT6_D2_Var_g', u'430AV2_ZT6_D2_SEg']]
df4.to_csv('../FHS project/Sleep notebook Copy/IPython_notebooks/input_files/430AV2_ZT6_D2_SymbolforIndexHedges.csv')

# %%
df4.head(10)  # check final ouput
# Out:
#                430AV2_ZT6_D2_Enrich  430AV2_ZT6_D2_Hedges_g  \
# MGI symbol
# 0610005C13Rik              0.089680                0.902413
# 0610008F07Rik             -0.040547               -0.177167
# 0610009B22Rik              0.062817                0.616777
# 0610009D07Rik              0.146680                1.714562
# 0610009O20Rik             -0.143390               -1.760885
# 0610010K14Rik              0.096367                0.434760
# 0610012G03Rik              0.130631                1.059977
# 0610031J06Rik              0.017660                0.109815
# 0610037L13Rik              0.092313                0.769596
# 0610040J01Rik              0.049873                0.796946
#
#                430AV2_ZT6_D2_Var_g  430AV2_ZT6_D2_SEg
# MGI symbol
# 0610005C13Rik             0.549529           0.741302
# 0610008F07Rik             0.484282           0.695904
# 0610009B22Rik             0.513368           0.716497
# 0610009D07Rik             0.768442           0.868837
# 0610009O20Rik             0.740060           0.860267
# 0610010K14Rik             0.497418           0.705279
# 0610012G03Rik             0.592152           0.767803
# 0610031J06Rik             0.482672           0.694746
# 0610037L13Rik             0.531023           0.728713
# 0610040J01Rik             0.534594           0.731159
