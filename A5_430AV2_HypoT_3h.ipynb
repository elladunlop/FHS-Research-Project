# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_2}-\bar{X_1}$$
#
# Let Group 1 be 3h Sleeping Hypothalamus Expression values and Group 2 be 3h SD Hypothalamus Expression values
#
# (S mean - SD mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviation} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and file IO
import numpy as np # numerical calculations
# %cd /Users/Ella1/Desktop/data sets 430AV2
# Out:
# /Users/Ella1/Desktop/data sets 430AV2

# %%
prefix = '430AV2_HypoT_3h_'   # define a prefix to add to column names (making indexing easier later)

# %%
# import the data file to a data frame 'df'
df=pd.read_table('DATASET-GSE6514.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.shape
# Out:
# (45101, 137)

# %%
# remove probes that are know to cross-hybridise to more than one target
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (40569, 137)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into S and SD groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites',
#        ...
#        'adjp-HypoT_12hS_vs_HypoT_12hSD', 'GSM149636_HypoT_12hSD.CEL',
#        'GSM149637_HypoT_12hSD.CEL', 'GSM149648_HypoT_12hSD.CEL',
#        'GSM149649_HypoT_12hSD.CEL', 'GSM149650_HypoT_12hSD.CEL',
#        'avg-HypoT_12hSD', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold'],
#       dtype='object', length=137)

# %%
# define regular expressions for sleep (S) and sleep dep (SD) filters 
s_filt ='HypoT_3hS.CEL'
sd_filt ='HypoT_3hSD.CEL'

# %%
df_s=df.filter(regex= s_filt)
df_s.head()
# Out:
#               GSM149601_HypoT_3hS.CEL  GSM149602_HypoT_3hS.CEL  \
# Probesets
# 1427138_at                    6.66009                  6.83341
# 1425600_a_at                  7.50817                  7.86638
# 1457168_at                    5.67372                  5.78951
# 1450135_at                    6.04249                  5.89659
# 1424014_at                    7.50105                  7.57047
#
#               GSM149603_HypoT_3hS.CEL  GSM149604_HypoT_3hS.CEL  \
# Probesets
# 1427138_at                    7.13931                  7.00522
# 1425600_a_at                  7.18785                  6.85622
# 1457168_at                    5.69763                  5.43336
# 1450135_at                    5.51381                  5.55955
# 1424014_at                    8.44307                  8.37000
#
#               GSM149605_HypoT_3hS.CEL
# Probesets
# 1427138_at                    6.61334
# 1425600_a_at                  6.25142
# 1457168_at                    5.47351
# 1450135_at                    5.38584
# 1424014_at                    8.26825

# %%
df_sd=df.filter(regex= sd_filt)
df_sd.head()
# Out:
#               GSM149606_HypoT_3hSD.CEL  GSM149607_HypoT_3hSD.CEL  \
# Probesets
# 1427138_at                     6.66695                   6.52740
# 1425600_a_at                   7.48415                   7.02924
# 1457168_at                     5.83585                   5.72586
# 1450135_at                     6.24634                   5.85096
# 1424014_at                     7.62093                   7.51731
#
#               GSM149608_HypoT_3hSD.CEL  GSM149609_HypoT_3hSD.CEL  \
# Probesets
# 1427138_at                     6.30358                   6.73212
# 1425600_a_at                   6.85651                   7.45120
# 1457168_at                     5.87868                   5.70601
# 1450135_at                     5.64197                   5.71443
# 1424014_at                     7.98004                   8.13447
#
#               GSM149610_HypoT_3hSD.CEL
# Probesets
# 1427138_at                     6.46545
# 1425600_a_at                   6.76965
# 1457168_at                     5.49476
# 1450135_at                     5.71497
# 1424014_at                     8.42482

# %% [markdown]
# ## Calculations

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=sd_filt).mean(axis=1) - df.filter(regex=s_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at     -0.311174
# 1425600_a_at   -0.015858
# 1457168_at      0.114686
# 1450135_at      0.154078
# 1424014_at     -0.095054
# Name: 430AV2_HypoT_3h_Enrich, dtype: float64

# %%
# Calculating Pooled StDev
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

StdevS = (Scount-1) * df.filter(regex=s_filt).var(axis=1)
StdevSD = (SDcount-1) * df.filter(regex=sd_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevS+StdevSD)/(Scount+ SDcount-2))

# %%
# Calculating Cohen's d
df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
#df[prefix+'poolStDev'].head()
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at     -1.568729
# 1425600_a_at   -0.031891
# 1457168_at      0.758371
# 1450135_at      0.591613
# 1424014_at     -0.228138
# Name: 430AV2_HypoT_3h_Cohens_d, dtype: float64

# %%
# Calculating J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(Scount+SDcount-1)))

# %%
# Calculating Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at     -1.438002
# 1425600_a_at   -0.029234
# 1457168_at      0.695173
# 1450135_at      0.542312
# 1424014_at     -0.209126
# Name: 430AV2_HypoT_3h_Hedges_g, dtype: float64

# %%
# Calculating Var_d
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

Ftop1 = Scount + SDcount
Ftop2 = Scount * SDcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(Scount + SDcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check output
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.523046
# 1425600_a_at    0.400051
# 1457168_at      0.428756
# 1450135_at      0.417500
# 1424014_at      0.402602
# Name: 430AV2_HypoT_3h_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
# Calculating SEg
df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by= '430AV2_HypoT_3h_Hedges_g', ascending=False, inplace=True)
df
# Out:
#                         Symbol  \
# Probesets
# 1452318_a_at            Hspa1b
# 1418206_at              Sdf2l1
# 1417879_at                Nenf
# 1438025_at              Mtrf1l
# 1427126_at              Hspa1b
# 1450843_a_at          Serpinh1
# 1452388_at              Hspa1a
# 1429169_at                Rbm3
# 1429165_at       3110001I22Rik
# 1428052_a_at             Zmym1
# 1422998_a_at             Glrx2
# 1449372_at              Dnajc3
# 1454014_a_at              Mkks
# 1452754_at              Creld2
# 1432271_a_at           Dcun1d5
# 1434540_a_at              Clta
# 1417394_at                Klf4
# 1422562_at                Rrad
# 1428331_at       2210016F16Rik
# 1428634_at             Twistnb
# 1423753_at               Bambi
# 1422481_at                Krt1
# 1422943_a_at             Hspb1
# 1417719_at               Sap30
# 1423771_at             Prkcdbp
# 1426784_at              Trim47
# 1417002_at       0610012G03Rik
# 1416077_at                 Adm
# 1418106_at                Hey2
# 1451944_a_at           Tnfsf11
# ...                        ...
# 1460437_at               Cyth4
# 1443151_at                 NaN
# 1420919_at                Sgk3
# 1439201_at               Usp14
# 1436308_at              Zfp292
# 1459864_at              Gpr146
# 1436467_at       D230004N17Rik
# 1455352_at       2610101N10Rik
# 1443954_at               Rad18
# 1454980_at                 NaN
# 1448989_a_at             Myo1b
# 1417301_at                Fzd6
# 1439192_at               Nova2
# 1444236_at            AW552393
# 1437240_at                Pgm2
# 1437149_at              Slc6a6
# 1432696_at       5830431M20Rik
# 1428917_at               Stx17
# 1435730_at       D930026N18Rik
# 1421932_at                 NaN
# 1437924_at                 NaN
# 1446815_at                 NaN
# 1431518_at              Ptchd3
# 1436228_at    Ctbp2 /// Zranb1
# 1453709_at                Grit
# 1446318_at                 NaN
# 1442567_at              Zbtb24
# 1440569_at            Slc16a10
# 1458397_at              622208
# 1452661_at                Tfrc
#
#                                                      Definition  \
# Probesets
# 1452318_a_at                              heat shock protein 1B
# 1418206_at                 stromal cell-derived factor 2-like 1
# 1417879_at                   neuron derived neurotrophic factor
# 1438025_at    mitochondrial translational release factor 1-l...
# 1427126_at                                heat shock protein 1B
# 1450843_a_at  serine (or cysteine) peptidase inhibitor, clad...
# 1452388_at                                heat shock protein 1A
# 1429169_at    RNA binding motif protein 3 [Source:MGI Symbol...
# 1429165_at    RIKEN cDNA 3110001I22 gene [Source:MGI Symbol;...
# 1428052_a_at               zinc finger, MYM domain containing 1
# 1422998_a_at                  glutaredoxin 2 (thioltransferase)
# 1449372_at         DnaJ (Hsp40) homolog, subfamily C, member 3A
# 1454014_a_at                  McKusick-Kaufman syndrome protein
# 1452754_at                cysteine-rich with EGF-like domains 2
# 1432271_a_at  DCN1, defective in cullin neddylation 1, domai...
# 1434540_a_at                  clathrin, light polypeptide (Lca)
# 1417394_at                          Kruppel-like factor 4 (gut)
# 1422562_at                 Ras-related associated with diabetes
# 1428331_at                           RIKEN cDNA 2210016F16 gene
# 1428634_at    TWIST neighbor [Source:MGI Symbol;Acc:MGI:106292]
# 1423753_at    BMP and activin membrane-bound inhibitor, homo...
# 1422481_at                                            keratin 1
# 1422943_a_at                               heat shock protein 1
# 1417719_at                          Sin3 associated polypeptide
# 1423771_at              protein kinase C, delta binding protein
# 1426784_at                          tripartite motif protein 47
# 1417002_at                           RIKEN cDNA 0610012G03 gene
# 1416077_at                                       adrenomedullin
# 1418106_at    hairy/enhancer-of-split related with YRPW motif 2
# 1451944_a_at  tumor necrosis factor (ligand) superfamily, me...
# ...                                                         ...
# 1460437_at      cytohesin 4 [Source:MGI Symbol;Acc:MGI:2441702]
# 1443151_at                                                  NaN
# 1420919_at              serum/glucocorticoid regulated kinase 3
# 1439201_at    ubiquitin specific peptidase 14 [Source:MGI Sy...
# 1436308_at                              zinc finger protein 292
# 1459864_at                       G protein-coupled receptor 146
# 1436467_at    RIKEN cDNA 2610203C20 gene [Source:MGI Symbol;...
# 1455352_at    U2 snRNP-associated SURP domain containing [So...
# 1443954_at    RAD18 homolog (S. cerevisiae) [Source:MGI Symb...
# 1454980_at                                                  NaN
# 1448989_a_at                                          myosin IB
# 1417301_at                      frizzled homolog 6 (Drosophila)
# 1439192_at    neuro-oncological ventral antigen 2 [Source:MG...
# 1444236_at                          expressed sequence AW552393
# 1437240_at                                 phosphoglucomutase 2
# 1437149_at    solute carrier family 6 (neurotransmitter tran...
# 1432696_at                           RIKEN cDNA 5830431M20 gene
# 1428917_at                                          syntaxin 17
# 1435730_at                           RIKEN cDNA D930026N18 gene
# 1421932_at                chromobox homolog 5 (Drosophila HP1a)
# 1437924_at                       Son cell proliferation protein
# 1446815_at                                                  NaN
# 1431518_at    patched domain containing 3 [Source:MGI Symbol...
# 1436228_at         zinc finger, RAN-binding domain containing 1
# 1453709_at    Rho GTPase activating protein 32 [Source:MGI S...
# 1446318_at                                                  NaN
# 1442567_at             zinc finger and BTB domain containing 24
# 1440569_at    solute carrier family 16 (monocarboxylic acid ...
# 1458397_at                                                  NaN
# 1452661_at                                 transferrin receptor
#
#                                          Ensembl_id     Entrez_id Unigene_id  \
# Probesets
# 1452318_a_at                     ENSMUSG00000090877         15511        NaN
# 1418206_at                       ENSMUSG00000022769         64136        NaN
# 1417879_at                       ENSMUSG00000037499         66208        NaN
# 1438025_at                       ENSMUSG00000019774        108853        NaN
# 1427126_at                       ENSMUSG00000090877         15511        NaN
# 1450843_a_at                     ENSMUSG00000070436         12406        NaN
# 1452388_at                       ENSMUSG00000091971        193740        NaN
# 1429169_at                       ENSMUSG00000031167         19652        NaN
# 1429165_at                       ENSMUSG00000079737         66598        NaN
# 1428052_a_at                     ENSMUSG00000043872         68310        NaN
# 1422998_a_at                     ENSMUSG00000018196         69367        NaN
# 1449372_at                       ENSMUSG00000022136     100037258        NaN
# 1454014_a_at                     ENSMUSG00000027274         59030        NaN
# 1452754_at                       ENSMUSG00000023272         76737        NaN
# 1432271_a_at                     ENSMUSG00000032002         76863        NaN
# 1434540_a_at                     ENSMUSG00000028478         12757        NaN
# 1417394_at                       ENSMUSG00000003032         16600        NaN
# 1422562_at                       ENSMUSG00000031880         56437        NaN
# 1428331_at                       ENSMUSG00000021550         70153        NaN
# 1428634_at                       ENSMUSG00000020561         28071        NaN
# 1423753_at                       ENSMUSG00000024232         68010        NaN
# 1422481_at                       ENSMUSG00000046834         16678        NaN
# 1422943_a_at  ENSMUSG00000004951|ENSMUSG00000078915         15507        NaN
# 1417719_at                       ENSMUSG00000031609         60406        NaN
# 1423771_at                       ENSMUSG00000037060        109042        NaN
# 1426784_at                       ENSMUSG00000020773        217333        NaN
# 1417002_at    ENSMUSG00000047112|ENSMUSG00000096232        106264        NaN
# 1416077_at                       ENSMUSG00000030790         11535        NaN
# 1418106_at                       ENSMUSG00000019789         15214        NaN
# 1451944_a_at                     ENSMUSG00000022015         21943        NaN
# ...                                             ...           ...        ...
# 1460437_at                       ENSMUSG00000018008         72318        NaN
# 1443151_at                                      NaN           NaN        NaN
# 1420919_at                       ENSMUSG00000025915        170755        NaN
# 1439201_at                       ENSMUSG00000047879         59025        NaN
# 1436308_at                       ENSMUSG00000039967         30046        NaN
# 1459864_at                       ENSMUSG00000044197         80290  Mm.270003
# 1436467_at                       ENSMUSG00000074415        320833        NaN
# 1455352_at                      ENSMUSG00000032407|         67958        NaN
# 1443954_at                       ENSMUSG00000030254         58186        NaN
# 1454980_at                                      NaN           NaN   Mm.28350
# 1448989_a_at                     ENSMUSG00000018417         17912        NaN
# 1417301_at                       ENSMUSG00000022297         14368        NaN
# 1439192_at                       ENSMUSG00000030411        384569        NaN
# 1444236_at                                      NaN         99922        NaN
# 1437240_at                                      NaN         72157  Mm.217764
# 1437149_at                       ENSMUSG00000030096         21366        NaN
# 1432696_at                                      NaN         76063        NaN
# 1428917_at                       ENSMUSG00000061455         67727        NaN
# 1435730_at                                      NaN        619317   Mm.41628
# 1421932_at                                      NaN        12419|        NaN
# 1437924_at                       ENSMUSG00000022961        |20658        NaN
# 1446815_at                                      NaN           NaN  Mm.422307
# 1431518_at                       ENSMUSG00000039198         74675        NaN
# 1436228_at                       ENSMUSG00000030967  13017|360216        NaN
# 1453709_at                       ENSMUSG00000041444        330914        NaN
# 1446318_at                                      NaN           NaN        NaN
# 1442567_at                                      NaN        268294  Mm.258475
# 1440569_at                                      NaN         72472  Mm.186778
# 1458397_at                       ENSMUSG00000097123        622208        NaN
# 1452661_at                       ENSMUSG00000022797         22042        NaN
#
#                                                      GO-Process  \
# Probesets
# 1452318_a_at  response to stress // anti-apoptosis // negati...
# 1418206_at                                                  NaN
# 1417879_at                positive regulation of MAPKKK cascade
# 1438025_at             translation // translational termination
# 1427126_at    response to stress // anti-apoptosis // negati...
# 1450843_a_at  collagen biosynthetic process // response to s...
# 1452388_at    DNA repair // response to stress // response t...
# 1429169_at    translation // response to cold // gene silenc...
# 1429165_at                                                  NaN
# 1428052_a_at                                                NaN
# 1422998_a_at  electron transport chain // response to organi...
# 1449372_at    response to unfolded protein // negative regul...
# 1454014_a_at  spermatid development // cellular protein meta...
# 1452754_at                                                  NaN
# 1432271_a_at                                                NaN
# 1434540_a_at  intracellular protein transport // vesicle-med...
# 1417394_at    response to chemical stimulus // epidermal cel...
# 1422562_at            small GTPase mediated signal transduction
# 1428331_at                                                  NaN
# 1428634_at                                        transcription
# 1423753_at    transforming growth factor beta receptor signa...
# 1422481_at                complement activation, lectin pathway
# 1422943_a_at             response to stress // response to heat
# 1417719_at    transcription // negative regulation of transc...
# 1423771_at      negative regulation of cell cycle // cell cycle
# 1426784_at                                                  NaN
# 1417002_at                                                  NaN
# 1416077_at    positive regulation of cell proliferation // n...
# 1418106_at    multicellular organismal development // vascul...
# 1451944_a_at  multicellular organismal development // organ ...
# ...                                                         ...
# 1460437_at        regulation of ARF protein signal transduction
# 1443151_at                                                  NaN
# 1420919_at    protein amino acid phosphorylation // cell com...
# 1439201_at    protein modification process // ubiquitin-depe...
# 1436308_at                                                  NaN
# 1459864_at    signal transduction // G-protein coupled recep...
# 1436467_at                                                  NaN
# 1455352_at                                       RNA processing
# 1443954_at    DNA repair // ubiquitin-dependent protein cata...
# 1454980_at                                                  NaN
# 1448989_a_at                                                NaN
# 1417301_at    neural tube closure // multicellular organisma...
# 1439192_at                                                  NaN
# 1444236_at                                                  NaN
# 1437240_at    glucose metabolic process // carbohydrate meta...
# 1437149_at    taurine transport // beta-alanine transport //...
# 1432696_at                                                  NaN
# 1428917_at    intracellular protein transport // transport /...
# 1435730_at                                                  NaN
# 1421932_at    chromatin assembly or disassembly // negative ...
# 1437924_at                                       anti-apoptosis
# 1446815_at                                                  NaN
# 1431518_at                                                  NaN
# 1436228_at    metabolic process // oxidation reduction // ne...
# 1453709_at    cell communication // signal transduction // R...
# 1446318_at                                                  NaN
# 1442567_at    transcription // regulation of transcription, ...
# 1440569_at                                            transport
# 1458397_at                                                  NaN
# 1452661_at         cellular iron ion homeostasis // endocytosis
#
#                                                     GO-Function  \
# Probesets
# 1452318_a_at  protein binding // nucleotide binding // ATP b...
# 1418206_at                                                  NaN
# 1417879_at    heme binding // transition metal ion binding /...
# 1438025_at    translation release factor activity, codon spe...
# 1427126_at    protein binding // nucleotide binding // ATP b...
# 1450843_a_at  protein binding // serine-type endopeptidase i...
# 1452388_at                    nucleotide binding // ATP binding
# 1429169_at    RNA binding // nucleic acid binding // nucleot...
# 1429165_at                                                  NaN
# 1428052_a_at  protein dimerization activity // zinc ion binding
# 1422998_a_at  2 iron, 2 sulfur cluster binding // transferas...
# 1449372_at    heat shock protein binding // protein kinase i...
# 1454014_a_at  protein binding // nucleotide binding // ATP b...
# 1452754_at                                  calcium ion binding
# 1432271_a_at                                                NaN
# 1434540_a_at  calcium ion binding // protein binding // stru...
# 1417394_at    nucleic acid binding // transcription factor a...
# 1422562_at    nucleotide binding // calmodulin binding // GT...
# 1428331_at                                                  NaN
# 1428634_at                 DNA-directed RNA polymerase activity
# 1423753_at                                                  NaN
# 1422481_at    sugar binding // protein binding // structural...
# 1422943_a_at                                                NaN
# 1417719_at    protein binding // transcription corepressor a...
# 1423771_at                             protein kinase C binding
# 1426784_at    protein binding // metal ion binding // zinc i...
# 1417002_at                                      protein binding
# 1416077_at                                     hormone activity
# 1418106_at    transcription factor activity // DNA binding /...
# 1451944_a_at  protein binding // receptor activity // cytoki...
# ...                                                         ...
# 1460437_at    ARF guanyl-nucleotide exchange factor activity...
# 1443151_at                                                  NaN
# 1420919_at    protein binding // protein kinase activity // ...
# 1439201_at    peptidase activity // hydrolase activity // cy...
# 1436308_at                                     zinc ion binding
# 1459864_at    receptor activity // signal transducer activit...
# 1436467_at                                                  NaN
# 1455352_at    nucleic acid binding // nucleotide binding // ...
# 1443954_at    nucleic acid binding // protein binding // DNA...
# 1454980_at                                                  NaN
# 1448989_a_at  motor activity // nucleotide binding // calmod...
# 1417301_at    transmembrane receptor activity // receptor ac...
# 1439192_at                       RNA binding // protein binding
# 1444236_at                                                  NaN
# 1437240_at    phosphoglucomutase activity // isomerase activ...
# 1437149_at    neurotransmitter:sodium symporter activity // ...
# 1432696_at                                                  NaN
# 1428917_at            SNAP receptor activity // protein binding
# 1435730_at                                                  NaN
# 1421932_at                 protein binding // chromatin binding
# 1437924_at    nucleic acid binding // RNA binding // double-...
# 1446815_at                                                  NaN
# 1431518_at                           hedgehog receptor activity
# 1436228_at    cofactor binding // NAD binding // catalytic a...
# 1453709_at    protein binding // phosphoinositide binding //...
# 1446318_at                                                  NaN
# 1442567_at    nucleic acid binding // transcription factor a...
# 1440569_at                                 transporter activity
# 1458397_at                                                  NaN
# 1452661_at    iron ion transmembrane transporter activity //...
#
#                                                    GO-Component  \
# Probesets
# 1452318_a_at  mitochondrion // intracellular // mitochondria...
# 1418206_at    endoplasmic reticulum lumen // endoplasmic ret...
# 1417879_at          extracellular region // extracellular space
# 1438025_at                           mitochondrion // cytoplasm
# 1427126_at    mitochondrion // intracellular // mitochondria...
# 1450843_a_at  cytoplasm // endoplasmic reticulum lumen // en...
# 1452388_at                    mitochondrion // cytoplasmic part
# 1429169_at                                                  NaN
# 1429165_at                                                  NaN
# 1428052_a_at                                            nucleus
# 1422998_a_at                           mitochondrion // nucleus
# 1449372_at                   cytoplasm // endoplasmic reticulum
# 1454014_a_at           motile secondary cilium // intracellular
# 1452754_at        extracellular region // endoplasmic reticulum
# 1432271_a_at                                                NaN
# 1434540_a_at  clathrin coat of coated pit // cytoplasmic ves...
# 1417394_at                             intracellular // nucleus
# 1422562_at                                                  NaN
# 1428331_at                                                  NaN
# 1428634_at                                              nucleus
# 1423753_at        cytoplasm // integral to membrane // membrane
# 1422481_at    intermediate filament // keratin filament // p...
# 1422943_a_at  intracellular // soluble fraction // contracti...
# 1417719_at    nucleus // histone deacetylase complex // Sin3...
# 1423771_at                                                  NaN
# 1426784_at                cytoplasm // intracellular // nucleus
# 1417002_at                                                  NaN
# 1416077_at    extracellular region // extracellular space //...
# 1418106_at              transcription factor complex // nucleus
# 1451944_a_at  extracellular space // extracellular region //...
# ...                                                         ...
# 1460437_at                                        intracellular
# 1443151_at                                                  NaN
# 1420919_at    cytoplasmic vesicle // endosome // cytoplasmic...
# 1439201_at                      synaptosome // soluble fraction
# 1436308_at                                        intracellular
# 1459864_at    integral to membrane // plasma membrane // mem...
# 1436467_at                                                  NaN
# 1455352_at                                                  NaN
# 1443954_at                                 chromatin // nucleus
# 1454980_at                                                  NaN
# 1448989_a_at                                     myosin complex
# 1417301_at    apicolateral plasma membrane // apical part of...
# 1439192_at                                                  NaN
# 1444236_at                                                  NaN
# 1437240_at                                            cytoplasm
# 1437149_at    integral to plasma membrane // integral to mem...
# 1432696_at                                                  NaN
# 1428917_at    smooth endoplasmic reticulum membrane // integ...
# 1435730_at                                                  NaN
# 1421932_at    kinetochore // chromosome, centromeric region ...
# 1437924_at                             intracellular // nucleus
# 1446815_at                                                  NaN
# 1431518_at                     integral to membrane // membrane
# 1436228_at    cytoplasm // synapse // intracellular // nucle...
# 1453709_at    endoplasmic reticulum membrane // postsynaptic...
# 1446318_at                                                  NaN
# 1442567_at                             intracellular // nucleus
# 1440569_at    basolateral plasma membrane // integral to mem...
# 1458397_at                                                  NaN
# 1452661_at    endosome // melanosome // extracellular region...
#
#                                                    Pathway_info  \
# Probesets
# 1452318_a_at                                                NaN
# 1418206_at                                                  NaN
# 1417879_at                                                  NaN
# 1438025_at                                                  NaN
# 1427126_at                                                  NaN
# 1450843_a_at     Endochondral Ossification:WP1270(WikiPathways)
# 1452388_at    Apoptosis Modulation by HSP70:WP166(WikiPathwa...
# 1429169_at    GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1429165_at                                                  NaN
# 1428052_a_at                                                NaN
# 1422998_a_at                                                NaN
# 1449372_at                                                  NaN
# 1454014_a_at                                                NaN
# 1452754_at                                                  NaN
# 1432271_a_at                                                NaN
# 1434540_a_at                                                NaN
# 1417394_at    PluriNetWork:WP1763(WikiPathways) // White fat...
# 1422562_at                 Insulin Signaling:WP65(WikiPathways)
# 1428331_at                                                  NaN
# 1428634_at                                                  NaN
# 1423753_at    GenMAPP-TGF_Beta_Signaling_Pathway // TGF Beta...
# 1422481_at                                                  NaN
# 1422943_a_at  IL-3 Signaling Pathway:WP373(WikiPathways) // ...
# 1417719_at    Delta-Notch Signaling Pathway:WP265(WikiPathways)
# 1423771_at                                                  NaN
# 1426784_at                                                  NaN
# 1417002_at                                                  NaN
# 1416077_at    GenMAPP-Smooth_muscle_contraction // Myometria...
# 1418106_at    Heart Development:WP2067(WikiPathways) // Delt...
# 1451944_a_at  Osteoblast:WP238(WikiPathways) // Osteoclast:W...
# ...                                                         ...
# 1460437_at                                                  NaN
# 1443151_at                                                  NaN
# 1420919_at                 Insulin Signaling:WP65(WikiPathways)
# 1439201_at                                                  NaN
# 1436308_at                                                  NaN
# 1459864_at                                 GenMAPP-GPCRDB_Other
# 1436467_at                                                  NaN
# 1455352_at                  mRNA processing:WP310(WikiPathways)
# 1443954_at                                                  NaN
# 1454980_at                                                  NaN
# 1448989_a_at                                                NaN
# 1417301_at    Wnt Signaling Pathway NetPath:WP539(WikiPathwa...
# 1439192_at                                                  NaN
# 1444236_at                                                  NaN
# 1437240_at                          GenMAPP-Glycogen_Metabolism
# 1437149_at                                                  NaN
# 1432696_at                                                  NaN
# 1428917_at                                                  NaN
# 1435730_at                                                  NaN
# 1421932_at                                                  NaN
# 1437924_at    GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1446815_at                                                  NaN
# 1431518_at                                                  NaN
# 1436228_at    Wnt Signaling Pathway NetPath:WP539(WikiPathwa...
# 1453709_at    XPodNet - protein-protein interactions in the ...
# 1446318_at                                                  NaN
# 1442567_at                                                  NaN
# 1440569_at                                                  NaN
# 1458397_at                                                  NaN
# 1452661_at                                                  NaN
#
#                                 Putative microRNA binding sites  \
# Probesets
# 1452318_a_at  mmu-miR-128(miRanda), mmu-miR-130a(miRanda), m...
# 1418206_at    mmu-miR-124(TargetScan|miRanda), mmu-miR-124ab...
# 1417879_at                                 mmu-miR-543(miRanda)
# 1438025_at    mmu-miR-128a(RNAhybrid|miRanda), mmu-miR-128b(...
# 1427126_at    mmu-miR-128(miRanda), mmu-miR-130a(miRanda), m...
# 1450843_a_at  mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...
# 1452388_at    mmu-miR-130a(miRanda), mmu-miR-130b(miRanda), ...
# 1429169_at    mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...
# 1429165_at    mmu-miR-136(miRanda), mmu-miR-154(miRanda), mm...
# 1428052_a_at  mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1422998_a_at  mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
# 1449372_at    mmu-miR-1(miRanda), mmu-miR-124(miRanda), mmu-...
# 1454014_a_at  mmu-miR-124(miRanda), mmu-miR-144(miRanda), mm...
# 1452754_at    mmu-miR-186(miRanda), mmu-miR-340-5p(TargetSca...
# 1432271_a_at  mmu-miR-1192(miRanda), mmu-miR-124(TargetScan)...
# 1434540_a_at  mmu-let-7d(RNAhybrid), mmu-let-7g(RNAhybrid), ...
# 1417394_at    mmu-miR-1(RNAhybrid|miRanda|pictar), mmu-miR-1...
# 1422562_at    mmu-miR-1192(miRanda), mmu-miR-143(miRanda), m...
# 1428331_at                                                  NaN
# 1428634_at    mmu-miR-10a(miRanda), mmu-miR-10b(miRanda), mm...
# 1423753_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1422481_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1422943_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1417719_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1423771_at    mmu-miR-291a-3p(miRanda), mmu-miR-294(miRanda)...
# 1426784_at            mmu-let-7i(miRanda), mmu-miR-122(miRanda)
# 1417002_at                                                  NaN
# 1416077_at    mmu-miR-1192(miRanda), mmu-miR-1297(TargetScan...
# 1418106_at    mmu-let-7b(miRanda), mmu-let-7c(miRanda), mmu-...
# 1451944_a_at  mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# ...                                                         ...
# 1460437_at    mmu-miR-122(miRanda), mmu-miR-128(miRanda), mm...
# 1443151_at                                                  NaN
# 1420919_at    mmu-miR-103(miRanda), mmu-miR-106a(miRanda), m...
# 1439201_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1436308_at    mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...
# 1459864_at    mmu-miR-103(miRanda), mmu-miR-105(TargetScan),...
# 1436467_at    mmu-miR-1192(miRanda), mmu-miR-125a-3p(miRanda...
# 1455352_at    mmu-miR-103(miRanda), mmu-miR-106a(RNAhybrid),...
# 1443954_at    mmu-let-7f(miRanda), mmu-miR-101a(miRanda), mm...
# 1454980_at                                                  NaN
# 1448989_a_at  mmu-miR-101a(miRanda), mmu-miR-101b(RNAhybrid|...
# 1417301_at    mmu-miR-101(TargetScan|pictar), mmu-miR-101a(m...
# 1439192_at    mmu-miR-107(RNAhybrid), mmu-miR-129-3p(RNAhybr...
# 1444236_at                                                  NaN
# 1437240_at                                                  NaN
# 1437149_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1432696_at                                                  NaN
# 1428917_at    mmu-let-7(TargetScan), mmu-let-7a(pictar), mmu...
# 1435730_at                                                  NaN
# 1421932_at                                                  NaN
# 1437924_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1446815_at                                                  NaN
# 1431518_at    mmu-miR-1192(miRanda), mmu-miR-130a(miRanda), ...
# 1436228_at    mmu-let-7e(miRanda), mmu-let-7g(miRanda), mmu-...
# 1453709_at    mmu-miR-101b(RNAhybrid|miRanda), mmu-miR-128(T...
# 1446318_at                                                  NaN
# 1442567_at                                                  NaN
# 1440569_at                                                  NaN
# 1458397_at                                                  NaN
# 1452661_at    mmu-miR-106b(miRanda), mmu-miR-124(TargetScan|...
#
#                      ...             ANOVA-adjp largest fold  \
# Probesets            ...
# 1460437_at                   -3.343310               1.065120
# 1443151_at                   -3.345926               1.066162
# 1420919_at                   -3.386021               1.082223
# 1439201_at                   -3.391950               1.084615
# 1436308_at                   -3.404688               1.089766
# 1459864_at                   -3.450652               1.108515
# 1436467_at                   -3.463395               1.113758
# 1455352_at                   -3.473531               1.117942
# 1443954_at                   -3.487348               1.123665
# 1454980_at                   -3.514739               1.135078
# 1448989_a_at                 -3.515826               1.135533
# 1417301_at                   -3.613419               1.176933
# 1439192_at                   -3.690989               1.210649
# 1444236_at                   -3.699706               1.214482
# 1437240_at                   -3.715174               1.221307
# 1437149_at                   -3.777391               1.249045
# 1432696_at                   -3.835123               1.275197
# 1428917_at                   -3.987174               1.345970
# 1435730_at                   -4.001334               1.352701
# 1421932_at                   -4.018004               1.360656
# 1437924_at                   -4.079183               1.390133
# 1446815_at                   -4.118910               1.409513
# 1431518_at                   -4.324388               1.512747
# 1436228_at                   -4.437973               1.571970
# 1453709_at                   -4.497635               1.603693
# 1446318_at                   -4.521953               1.616744
# 1442567_at                   -4.629683               1.675410
# 1440569_at                   -4.986860               1.879795
# 1458397_at                   -5.474329               2.183236
# 1452661_at                   -5.633630               2.288530
#
#               430AV2_HypoT_3h_Var_g  430AV2_HypoT_3h_SEg
# Probesets
# 1452318_a_at               2.083528             1.443443
# 1418206_at                 1.952223             1.397220
# 1417879_at                 1.627653             1.275795
# 1438025_at                 1.477771             1.215636
# 1427126_at                 1.474033             1.214098
# 1450843_a_at               1.410392             1.187599
# 1452388_at                 1.389975             1.178972
# 1429169_at                 1.352764             1.163084
# 1429165_at                 1.309875             1.144498
# 1428052_a_at               1.301883             1.141001
# 1422998_a_at               1.245653             1.116088
# 1449372_at                 1.233710             1.110725
# 1454014_a_at               1.190481             1.091092
# 1452754_at                 1.150317             1.072528
# 1432271_a_at               1.138275             1.066900
# 1434540_a_at               1.126929             1.061569
# 1417394_at                 1.098703             1.048190
# 1422562_at                 1.085287             1.041771
# 1428331_at                 1.084119             1.041210
# 1428634_at                 1.075760             1.037188
# 1423753_at                 1.007975             1.003980
# 1422481_at                 0.988309             0.994137
# 1422943_a_at               0.982224             0.991072
# 1417719_at                 0.980733             0.990320
# 1423771_at                 0.978142             0.989011
# 1426784_at                 0.973888             0.986858
# 1417002_at                 0.973050             0.986433
# 1416077_at                 0.969420             0.984591
# 1418106_at                 0.937435             0.968212
# 1451944_a_at               0.910674             0.954292
# ...                             ...                  ...
# 1460437_at                 0.894997             0.946043
# 1443151_at                 0.895872             0.946505
# 1420919_at                 0.909368             0.953608
# 1439201_at                 0.911377             0.954661
# 1436308_at                 0.915706             0.956925
# 1459864_at                 0.931461             0.965122
# 1436467_at                 0.935866             0.967402
# 1455352_at                 0.939382             0.969217
# 1443954_at                 0.944191             0.971695
# 1454980_at                 0.953781             0.976617
# 1448989_a_at               0.954163             0.976813
# 1417301_at                 0.988951             0.994460
# 1439192_at                 1.017281             1.008604
# 1444236_at                 1.020502             1.010199
# 1437240_at                 1.026237             1.013034
# 1437149_at                 1.049545             1.024473
# 1432696_at                 1.071519             1.035142
# 1428917_at                 1.130989             1.063480
# 1435730_at                 1.136645             1.066135
# 1421932_at                 1.143329             1.069266
# 1437924_at                 1.168098             1.080786
# 1446815_at                 1.184382             1.088293
# 1431518_at                 1.271128             1.127443
# 1436228_at                 1.320891             1.149300
# 1453709_at                 1.347547             1.160839
# 1446318_at                 1.358514             1.165553
# 1442567_at                 1.407809             1.186511
# 1440569_at                 1.579550             1.256801
# 1458397_at                 1.834525             1.354446
# 1452661_at                 1.923001             1.386723
#
# [40569 rows x 145 columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites',
#        ...
#        'ANOVA-adjp', 'largest fold', '430AV2_HypoT_3h_Enrich',
#        '430AV2_HypoT_3h_poolStDev', '430AV2_HypoT_3h_Cohens_d',
#        '430AV2_HypoT_3h_J', '430AV2_HypoT_3h_Hedges_g',
#        '430AV2_HypoT_3h_Var_d', '430AV2_HypoT_3h_Var_g',
#        '430AV2_HypoT_3h_SEg'],
#       dtype='object', length=145)

# %% [markdown]
# ### Import key file from BioMart and index probesets to MGI gene symbols

# %%
dfX=pd.read_table('../FHS project/Sleep notebook Copy/BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[3])
 
dfX.pop('Affy mouse430 2 probeset') # remove 430V2 probeset info (not needed for 430AV2 indexing)
dfX.head(5)
# Out:
#                               Ensembl Gene ID  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ENSMUSG00000039221
# NaN                        ENSMUSG00000095611
# 1417730_at                 ENSMUSG00000061731
# 1417730_at                 ENSMUSG00000061731
# NaN                        ENSMUSG00000061731
#
#                                                                  Description  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                        predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# NaN                        exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                           MGI symbol
# Affy mouse430a 2 probeset
# 1417126_a_at                 Rpl22l1
# NaN                          Gm10597
# 1417730_at                      Ext1
# 1417730_at                      Ext1
# NaN                             Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]   # checking that no duplicate entries exist in the dataframe
# Out:
# Empty DataFrame
# Columns: [GSM149516_CerCx_3hS.CEL, GSM149517_CerCx_3hS.CEL, GSM149518_CerCx_3hS.CEL, GSM149519_CerCx_3hS.CEL, GSM149520_CerCx_3hS.CEL, avg-CerCx_3hS, log_fold-CerCx_3hS_vs_CerCx_3hSD, fold-CerCx_3hS_vs_CerCx_3hSD, rawp-CerCx_3hS_vs_CerCx_3hSD, adjp-CerCx_3hS_vs_CerCx_3hSD, GSM149521_CerCx_3hSD.CEL, GSM149522_CerCx_3hSD.CEL, GSM149523_CerCx_3hSD.CEL, GSM149524_CerCx_3hSD.CEL, GSM149525_CerCx_3hSD.CEL, avg-CerCx_3hSD, GSM149540_CerCx_6hS.CEL, GSM149541_CerCx_6hS.CEL, GSM149542_CerCx_6hS.CEL, GSM149543_CerCx_6hS.CEL, GSM149544_CerCx_6hS.CEL, avg-CerCx_6hS, log_fold-CerCx_6hS_vs_CerCx_6hSD, fold-CerCx_6hS_vs_CerCx_6hSD, rawp-CerCx_6hS_vs_CerCx_6hSD, adjp-CerCx_6hS_vs_CerCx_6hSD, GSM149545_CerCx_6hSD.CEL, GSM149546_CerCx_6hSD.CEL, GSM149547_CerCx_6hSD.CEL, GSM149548_CerCx_6hSD.CEL, GSM149549_CerCx_6hSD.CEL, avg-CerCx_6hSD, GSM149550_CerCx_9hS.CEL, GSM149551_CerCx_9hS.CEL, GSM149552_CerCx_9hS.CEL, GSM149553_CerCx_9hS.CEL, GSM149554_CerCx_9hS.CEL, avg-CerCx_9hS, log_fold-CerCx_9hS_vs_CerCx_9hSD, fold-CerCx_9hS_vs_CerCx_9hSD, rawp-CerCx_9hS_vs_CerCx_9hSD, adjp-CerCx_9hS_vs_CerCx_9hSD, GSM149555_CerCx_9hSD.CEL, GSM149556_CerCx_9hSD.CEL, GSM149557_CerCx_9hSD.CEL, GSM149558_CerCx_9hSD.CEL, GSM149559_CerCx_9hSD.CEL, avg-CerCx_9hSD, GSM149560_CerCx_12hS.CEL, GSM149561_CerCx_12hS.CEL, GSM149562_CerCx_12hS.CEL, GSM149563_CerCx_12hS.CEL, GSM149564_CerCx_12hS.CEL, avg-CerCx_12hS, log_fold-CerCx_12hS_vs_CerCx_12hSD, fold-CerCx_12hS_vs_CerCx_12hSD, rawp-CerCx_12hS_vs_CerCx_12hSD, adjp-CerCx_12hS_vs_CerCx_12hSD, GSM149565_CerCx_12hSD.CEL, GSM149566_CerCx_12hSD.CEL, GSM149567_CerCx_12hSD.CEL, GSM149568_CerCx_12hSD.CEL, GSM149575_CerCx_12hSD.CEL, avg-CerCx_12hSD, GSM149601_HypoT_3hS.CEL, GSM149602_HypoT_3hS.CEL, GSM149603_HypoT_3hS.CEL, GSM149604_HypoT_3hS.CEL, GSM149605_HypoT_3hS.CEL, avg-HypoT_3hS, log_fold-HypoT_3hS_vs_HypoT_3hSD, fold-HypoT_3hS_vs_HypoT_3hSD, rawp-HypoT_3hS_vs_HypoT_3hSD, adjp-HypoT_3hS_vs_HypoT_3hSD, GSM149606_HypoT_3hSD.CEL, GSM149607_HypoT_3hSD.CEL, GSM149608_HypoT_3hSD.CEL, GSM149609_HypoT_3hSD.CEL, GSM149610_HypoT_3hSD.CEL, avg-HypoT_3hSD, GSM149611_HypoT_6hS.CEL, GSM149612_HypoT_6hS.CEL, GSM149613_HypoT_6hS.CEL, GSM149614_HypoT_6hS.CEL, GSM149615_HypoT_6hS.CEL, avg-HypoT_6hS, log_fold-HypoT_6hS_vs_HypoT_6hSD, fold-HypoT_6hS_vs_HypoT_6hSD, rawp-HypoT_6hS_vs_HypoT_6hSD, adjp-HypoT_6hS_vs_HypoT_6hSD, GSM149616_HypoT_6hSD.CEL, GSM149617_HypoT_6hSD.CEL, GSM149618_HypoT_6hSD.CEL, GSM149619_HypoT_6hSD.CEL, GSM149620_HypoT_6hSD.CEL, avg-HypoT_6hSD, GSM149621_HypoT_9hS.CEL, GSM149622_HypoT_9hS.CEL, GSM149623_HypoT_9hS.CEL, GSM149624_HypoT_9hS.CEL, ...]
# Index: []
#
# [0 rows x 133 columns]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average S and SD expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-SD', u'avg-S', u'log_fold-S_vs_SD']]
# df3.columns =[prefix+'avg-SD', prefix+'avg-S', prefix+'log_fold-S_vs_SD']
# df3.to_csv('input_files/430AV2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430AV2_HypoT_3h_Enrich',u'430AV2_HypoT_3h_Hedges_g', u'430AV2_HypoT_3h_Var_g', u'430AV2_HypoT_3h_SEg']]
df4.to_csv('../FHS project/Sleep notebook Copy/IPython_notebooks/input_files/430AV2_HypoT_3h_SymbolforIndexHedges.csv')

# %%
df4.head(10)  # check final ouput
# Out:
#                430AV2_HypoT_3h_Enrich  430AV2_HypoT_3h_Hedges_g  \
# MGI symbol
# 0610005C13Rik                0.084930                  0.382248
# 0610008F07Rik                0.118778                  0.664416
# 0610009B22Rik                0.102728                  0.650049
# 0610009D07Rik                0.177883                  0.313462
# 0610009O20Rik               -0.003892                 -0.028528
# 0610010K14Rik               -0.105490                 -0.326858
# 0610012G03Rik                0.484069                  2.023565
# 0610031J06Rik               -0.174324                 -0.817487
# 0610037L13Rik               -0.061218                 -0.601995
# 0610040J01Rik                0.156828                  1.577280
#
#                430AV2_HypoT_3h_Var_g  430AV2_HypoT_3h_SEg
# MGI symbol
# 0610005C13Rik               0.343417             0.586018
# 0610008F07Rik               0.358184             0.598484
# 0610009B22Rik               0.357239             0.597695
# 0610009D07Rik               0.341083             0.584022
# 0610009O20Rik               0.336152             0.579786
# 0610010K14Rik               0.341453             0.584340
# 0610012G03Rik               0.600572             0.757936
# 0610031J06Rik               0.369525             0.607886
# 0610037L13Rik               0.354231             0.595173
# 0610040J01Rik               0.460502             0.678603
