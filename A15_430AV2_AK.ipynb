# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_2}-\bar{X_1}$$
#
# Let Group 1 be 6hSleeping whole brain AKR/J strain (AK) Expression values and Group 2 be 6hSD whole brain AKR/J strain (AK) Expression values
#
# (S mean - SD mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviation} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and file IO
import numpy as np # numerical calculations
# %cd /Users/Ella1/Desktop/data sets 430AV2
# Out:
# /Users/Ella1/Desktop/data sets 430AV2

# %%
prefix = '430AV2_WB_AK_'   # define a prefix to add to column names (making indexing easier later)

# %%
# import the data file to a data frame 'df'
df=pd.read_table('DATASET-GSE9441.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.shape
# Out:
# (45101, 51)

# %%
# remove probes that are know to cross-hybridise to more than one target
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (40569, 51)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into S and SD groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239832_AK_S.CEL', 'GSM239833_AK_S.CEL',
#        'GSM239834_AK_S.CEL', 'avg-AK_S', 'log_fold-AK_S_vs_AK_SD',
#        'fold-AK_S_vs_AK_SD', 'rawp-AK_S_vs_AK_SD', 'adjp-AK_S_vs_AK_SD',
#        'GSM239835_AK_SD.CEL', 'GSM239836_AK_SD.CEL', 'GSM239837_AK_SD.CEL',
#        'avg-AK_SD', 'GSM239838_B6_S.CEL', 'GSM239839_B6_S.CEL',
#        'GSM239840_B6_S.CEL', 'avg-B6_S', 'log_fold-B6_S_vs_B6_SD',
#        'fold-B6_S_vs_B6_SD', 'rawp-B6_S_vs_B6_SD', 'adjp-B6_S_vs_B6_SD',
#        'GSM239841_B6_SD.CEL', 'GSM239842_B6_SD.CEL', 'GSM239843_B6_SD.CEL',
#        'avg-B6_SD', 'GSM239844_D2_S.CEL', 'GSM239845_D2_S.CEL',
#        'GSM239846_D2_S.CEL', 'avg-D2_S', 'log_fold-D2_S_vs_D2_SD',
#        'fold-D2_S_vs_D2_SD', 'rawp-D2_S_vs_D2_SD', 'adjp-D2_S_vs_D2_SD',
#        'GSM239847_D2_SD.CEL', 'GSM239848_D2_SD.CEL', 'GSM239849_D2_SD.CEL',
#        'avg-D2_SD', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold'],
#       dtype='object')

# %%
# define regular expressions for sleep (S) and sleep dep (SD) filters 
s_filt ='AK_S.CEL'
sd_filt ='AK_SD.CEL'

# %%
df_s=df.filter(regex= s_filt)
df_s.head()
# Out:
#               GSM239832_AK_S.CEL  GSM239833_AK_S.CEL  GSM239834_AK_S.CEL
# Probesets
# 1427138_at               5.10971             5.03325             5.28008
# 1425600_a_at             6.69959             6.69525             6.73935
# 1457168_at               4.00329             4.47225             4.26492
# 1450135_at               4.02864             4.25284             4.33413
# 1424014_at               7.87437             7.91219             7.90768

# %%
df_sd=df.filter(regex= sd_filt)
df_sd.head()
# Out:
#               GSM239835_AK_SD.CEL  GSM239836_AK_SD.CEL  GSM239837_AK_SD.CEL
# Probesets
# 1427138_at                4.92819              4.84399              5.22099
# 1425600_a_at              6.42856              6.60830              6.94887
# 1457168_at                4.20079              4.11243              4.48287
# 1450135_at                4.06130              3.93757              3.78229
# 1424014_at                7.97069              7.86162              7.92039

# %% [markdown]
# ## Calculations

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=sd_filt).mean(axis=1) - df.filter(regex=s_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at     -0.143290
# 1425600_a_at   -0.049487
# 1457168_at      0.018543
# 1450135_at     -0.278150
# 1424014_at      0.019487
# Name: 430AV2_WB_AK_Enrich, dtype: float64

# %%
# Calculating Pooled StDev
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

StdevS = (Scount-1) * df.filter(regex=s_filt).var(axis=1)
StdevSD = (SDcount-1) * df.filter(regex=sd_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevS+StdevSD)/(Scount+ SDcount-2))

# %%
# Calculating Cohen's d
df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
#df[prefix+'poolStDev'].head()
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at     -0.863094
# 1425600_a_at   -0.263714
# 1457168_at      0.086150
# 1450135_at     -1.863099
# 1424014_at      0.472152
# Name: 430AV2_WB_AK_Cohens_d, dtype: float64

# %%
# Calculating J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(Scount+SDcount-1)))

# %%
# Calculating Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at     -0.733630
# 1425600_a_at   -0.224157
# 1457168_at      0.073228
# 1450135_at     -1.583634
# 1424014_at      0.401330
# Name: 430AV2_WB_AK_Hedges_g, dtype: float64

# %%
# Calculating Var_d
Scount = df.filter(regex=s_filt).count(axis=1)
SDcount = df.filter(regex=sd_filt).count(axis=1)

Ftop1 = Scount + SDcount
Ftop2 = Scount * SDcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(Scount + SDcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check output
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.728744
# 1425600_a_at    0.672462
# 1457168_at      0.667285
# 1450135_at      0.955928
# 1424014_at      0.685244
# Name: 430AV2_WB_AK_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
# Calculating SEg
df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by= '430AV2_WB_AK_Hedges_g', ascending=False, inplace=True)
df
# Out:
#                                    Symbol  \
# Probesets
# 1440227_at                         Slc5a3
# 1438040_a_at                      Hsp90b1
# 1458636_at                         Rnf219
# 1434228_at                          Ppm2c
# 1417185_at                           Ly6a
# 1417606_a_at                         Calr
# 1450768_at          Dlg1 /// LOC100047603
# 1416064_a_at                        Hspa5
# 1435246_at                          Paqr8
# 1420886_a_at                         Xbp1
# 1421768_a_at                       Homer1
# 1460179_at                         Dnaja1
# 1456125_a_at          Dynll1 /// EG627788
# 1418587_at                          Traf3
# 1449431_at                          Trpc6
# 1422256_at                          Sstr2
# 1423455_at    ENSMUSG00000045799 /// Ptma
# 1460240_a_at                       Hnrnpc
# 1452462_a_at                         Banp
# 1450863_a_at                        Dclk1
# 1460310_a_at                           Gh
# 1423894_a_at                       Dalrd3
# 1454042_a_at                        Srpk1
# 1423648_at                          Pdia6
# 1450061_at                           Enc1
# 1416537_at                         Creld1
# 1416568_a_at                        Acin1
# 1434562_at                          Mfap3
# 1424533_a_at                      Ccdc137
# 1434382_at       LOC100044221 /// Serinc2
# ...                                   ...
# 1422635_at                           Ache
# 1429066_at                  4930565B19Rik
# 1451566_at                         Zfp810
# 1435193_at                  A230050P20Rik
# 1428597_at                        Tbc1d9b
# 1436066_at                          Kalrn
# 1435445_at                          Ccnt2
# 1416332_at                          Cirbp
# 1448498_at                        Rps6ka4
# 1418107_at                          Tcea2
# 1423983_at                         Sez6l2
# 1434509_at                        Rapgef6
# 1418174_at                            Dbp
# 1437464_at                         Spata7
# 1432273_a_at                         Darc
# 1435854_at                         Opalin
# 1449423_at                          Mast1
# 1429639_at                          Prei4
# 1422660_at                           Rbm3
# 1453456_at                  2900084O13Rik
# 1426666_a_at                       Unc84a
# 1449123_at                          Itih3
# 1436766_at                         Luc7l2
# 1452661_at                           Tfrc
# 1433643_at                       Cacna2d1
# 1452268_at                         Fam76b
# 1438199_at                       AI316807
# 1426380_at                          Eif4b
# 1460586_at                          Megf8
# 1415770_at                           Wdr6
#
#                                                      Definition  \
# Probesets
# 1440227_at    solute carrier family 5 (inositol transporters...
# 1438040_a_at    heat shock protein 90kDa beta (Grp94), member 1
# 1458636_at    ring finger protein 219 [Source:MGI Symbol;Acc...
# 1434228_at    pyruvate dehyrogenase phosphatase catalytic su...
# 1417185_at                lymphocyte antigen 6 complex, locus A
# 1417606_a_at                                       calreticulin
# 1450768_at                  discs, large homolog 1 (Drosophila)
# 1416064_a_at                               heat shock protein 5
# 1435246_at    progestin and adipoQ receptor family member VI...
# 1420886_a_at                            X-box binding protein 1
# 1421768_a_at                       homer homolog 1 (Drosophila)
# 1460179_at          DnaJ (Hsp40) homolog, subfamily A, member 1
# 1456125_a_at                      dynein light chain LC8-type 1
# 1418587_at                     Tnf receptor-associated factor 3
# 1449431_at    transient receptor potential cation channel, s...
# 1422256_at                              somatostatin receptor 2
# 1423455_at                                 predicted gene 15466
# 1460240_a_at          heterogeneous nuclear ribonucleoprotein C
# 1452462_a_at                    Btg3 associated nuclear protein
# 1450863_a_at                         doublecortin-like kinase 1
# 1460310_a_at                                     growth hormone
# 1423894_a_at         DALR anticodon binding domain containing 3
# 1454042_a_at     serine/arginine-rich protein specific kinase 1
# 1423648_at             protein disulfide isomerase associated 6
# 1450061_at                           ectodermal-neural cortex 1
# 1416537_at                cysteine-rich with EGF-like domains 1
# 1416568_a_at         apoptotic chromatin condensation inducer 1
# 1434562_at    microfibrillar-associated protein 3 [Source:MG...
# 1424533_a_at                  coiled-coil domain containing 137
# 1434382_at    serine incorporator 2 [Source:MGI Symbol;Acc:M...
# ...                                                         ...
# 1422635_at                                 acetylcholinesterase
# 1429066_at                           RIKEN cDNA 4930565B19 gene
# 1451566_at                              zinc finger protein 810
# 1435193_at                           RIKEN cDNA A230050P20 gene
# 1428597_at    TBC1 domain family, member 9B [Source:MGI Symb...
# 1436066_at                               kalirin, RhoGEF kinase
# 1435445_at        cyclin T2 [Source:MGI Symbol;Acc:MGI:1920199]
# 1416332_at                   cold inducible RNA binding protein
# 1448498_at           ribosomal protein S6 kinase, polypeptide 4
# 1418107_at           transcription elongation factor A (SII), 2
# 1423983_at                     seizure related 6 homolog like 2
# 1434509_at    Rap guanine nucleotide exchange factor (GEF) 6...
# 1418174_at              D site albumin promoter binding protein
# 1437464_at    spermatogenesis associated 7 [Source:MGI Symbo...
# 1432273_a_at              Duffy blood group, chemokine receptor
# 1435854_at    oligodendrocytic myelin paranodal and inner lo...
# 1449423_at     microtubule associated serine/threonine kinase 1
# 1429639_at    glycerophosphocholine phosphodiesterase GDE1 h...
# 1422660_at               similar to RNA binding motif protein 3
# 1453456_at                           RIKEN cDNA 2900084O13 gene
# 1426666_a_at                 Sad1 and UNC84 domain containing 1
# 1449123_at         inter-alpha trypsin inhibitor, heavy chain 3
# 1436766_at    LUC7-like 2 (S. cerevisiae) [Source:MGI Symbol...
# 1452661_at                                 transferrin receptor
# 1433643_at    calcium channel, voltage-dependent, alpha2/del...
# 1452268_at                           RIKEN cDNA 2810485I05 gene
# 1438199_at                          expressed sequence AI316807
# 1426380_at          eukaryotic translation initiation factor 4B
# 1460586_at    multiple EGF-like-domains 8 [Source:MGI Symbol...
# 1415770_at                                   WD repeat domain 6
#
#                                                      Ensembl_id  \
# Probesets
# 1440227_at                                   ENSMUSG00000089774
# 1438040_a_at                                 ENSMUSG00000020048
# 1458636_at                                   ENSMUSG00000022120
# 1434228_at                                   ENSMUSG00000049225
# 1417185_at                                   ENSMUSG00000075602
# 1417606_a_at              ENSMUSG00000003814|ENSMUSG00000081731
# 1450768_at                                   ENSMUSG00000022770
# 1416064_a_at                                 ENSMUSG00000026864
# 1435246_at                                   ENSMUSG00000025931
# 1420886_a_at                                 ENSMUSG00000020484
# 1421768_a_at                                 ENSMUSG00000007617
# 1460179_at                                   ENSMUSG00000028410
# 1456125_a_at              ENSMUSG00000009013|ENSMUSG00000090737
# 1418587_at                                   ENSMUSG00000021277
# 1449431_at                                   ENSMUSG00000031997
# 1422256_at                                   ENSMUSG00000047904
# 1423455_at    ENSMUSG00000096544|ENSMUSG00000095614|ENSMUSG0...
# 1460240_a_at                                 ENSMUSG00000060373
# 1452462_a_at                                 ENSMUSG00000025316
# 1450863_a_at                                 ENSMUSG00000027797
# 1460310_a_at                                 ENSMUSG00000020713
# 1423894_a_at                                 ENSMUSG00000019039
# 1454042_a_at                                 ENSMUSG00000004865
# 1423648_at                                   ENSMUSG00000020571
# 1450061_at                                   ENSMUSG00000041773
# 1416537_at                                   ENSMUSG00000030284
# 1416568_a_at                                 ENSMUSG00000022185
# 1434562_at                                   ENSMUSG00000020522
# 1424533_a_at                                ENSMUSG00000049957|
# 1434382_at                                   ENSMUSG00000023232
# ...                                                         ...
# 1422635_at                                   ENSMUSG00000023328
# 1429066_at                                                  NaN
# 1451566_at                                   ENSMUSG00000066829
# 1435193_at                                   ENSMUSG00000038884
# 1428597_at                                   ENSMUSG00000036644
# 1436066_at                                   ENSMUSG00000061751
# 1435445_at                                   ENSMUSG00000026349
# 1416332_at                                   ENSMUSG00000045193
# 1448498_at                                   ENSMUSG00000024952
# 1418107_at                                   ENSMUSG00000059540
# 1423983_at                                   ENSMUSG00000030683
# 1434509_at                                   ENSMUSG00000037533
# 1418174_at                                   ENSMUSG00000059824
# 1437464_at                                   ENSMUSG00000021007
# 1432273_a_at              ENSMUSG00000037872|ENSMUSG00000005338
# 1435854_at                                   ENSMUSG00000050121
# 1449423_at                                   ENSMUSG00000053693
# 1429639_at                                   ENSMUSG00000027346
# 1422660_at    ENSMUSG00000031167|ENSMUSG00000081535|ENSMUSG0...
# 1453456_at                                                  NaN
# 1426666_a_at                                 ENSMUSG00000036817
# 1449123_at                                   ENSMUSG00000006522
# 1436766_at                                   ENSMUSG00000029823
# 1452661_at                                   ENSMUSG00000022797
# 1433643_at                ENSMUSG00000040118|ENSMUSG00000073202
# 1452268_at                                   ENSMUSG00000037808
# 1438199_at                                   ENSMUSG00000031534
# 1426380_at                                   ENSMUSG00000058655
# 1460586_at                                   ENSMUSG00000045039
# 1415770_at                                   ENSMUSG00000066357
#
#                               Entrez_id Unigene_id  \
# Probesets
# 1440227_at                        53881        NaN
# 1438040_a_at                      22027        NaN
# 1458636_at                        72486        NaN
# 1434228_at                       381511        NaN
# 1417185_at                       110454        NaN
# 1417606_a_at                      12317        NaN
# 1450768_at              100047603|13383        NaN
# 1416064_a_at                      14828        NaN
# 1435246_at                        74229        NaN
# 1420886_a_at                      22433        NaN
# 1421768_a_at                      26556        NaN
# 1460179_at                        15502        NaN
# 1456125_a_at               56455|627788        NaN
# 1418587_at                        22031        NaN
# 1449431_at                        22068        NaN
# 1422256_at                        20606        NaN
# 1423455_at    19231|100504173|100041948        NaN
# 1460240_a_at                      15381        NaN
# 1452462_a_at                      53325        NaN
# 1450863_a_at                      13175        NaN
# 1460310_a_at                      14599        NaN
# 1423894_a_at                      67789        NaN
# 1454042_a_at                      20815        NaN
# 1423648_at                        71853        NaN
# 1450061_at                        13803        NaN
# 1416537_at                       171508        NaN
# 1416568_a_at                      56215        NaN
# 1434562_at                       216760        NaN
# 1424533_a_at                      67291        NaN
# 1434382_at             100044221|230779        NaN
# ...                                 ...        ...
# 1422635_at                        11423        NaN
# 1429066_at                        75325        NaN
# 1451566_at                       235050        NaN
# 1435193_at                       319278        NaN
# 1428597_at                        76795        NaN
# 1436066_at                       545156        NaN
# 1435445_at                        72949        NaN
# 1416332_at                        12696        NaN
# 1448498_at                        56613        NaN
# 1418107_at                        21400        NaN
# 1423983_at                       233878        NaN
# 1434509_at                       192786        NaN
# 1418174_at                        13170        NaN
# 1437464_at                       104871        NaN
# 1432273_a_at                      13349        NaN
# 1435854_at                       226115        NaN
# 1449423_at                        56527        NaN
# 1429639_at                        74182        NaN
# 1422660_at              19652|100043257        NaN
# 1453456_at                        73080        NaN
# 1426666_a_at                      77053        NaN
# 1449123_at                        16426        NaN
# 1436766_at             100861853|192196        NaN
# 1452661_at                        22042        NaN
# 1433643_at                        12293        NaN
# 1452268_at                        72826        NaN
# 1438199_at                       102032        NaN
# 1426380_at                        75705        NaN
# 1460586_at                       269878        NaN
# 1415770_at                        83669        NaN
#
#                                                      GO-Process  \
# Probesets
# 1440227_at    peripheral nervous system development // ion t...
# 1438040_a_at              response to stress // protein folding
# 1458636_at                                                  NaN
# 1434228_at                 protein amino acid dephosphorylation
# 1417185_at                                                  NaN
# 1417606_a_at  cortical actin cytoskeleton organization // se...
# 1450768_at    positive regulation of multicellular organism ...
# 1416064_a_at         response to stress // ER overload response
# 1435246_at                                                  NaN
# 1420886_a_at  transcription // regulation of transcription, ...
# 1421768_a_at  metabotropic glutamate receptor signaling path...
# 1460179_at    androgen receptor signaling pathway // spermat...
# 1456125_a_at  microtubule-based movement // negative regulat...
# 1418587_at    regulation of apoptosis // apoptosis // signal...
# 1449431_at    ion transport // calcium ion transport // elev...
# 1422256_at    neuropeptide signaling pathway // signal trans...
# 1423455_at                                                  NaN
# 1460240_a_at                    RNA splicing // mRNA processing
# 1452462_a_at  transcription // multicellular organismal deve...
# 1450863_a_at  dendrite morphogenesis // multicellular organi...
# 1460310_a_at  response to food // positive regulation of mul...
# 1423894_a_at  tRNA aminoacylation for protein translation //...
# 1454042_a_at  protein kinase cascade // protein amino acid p...
# 1423648_at                               cell redox homeostasis
# 1450061_at    multicellular organismal development // ubiqui...
# 1416537_at                                                  NaN
# 1416568_a_at  apoptosis // apoptotic program // positive reg...
# 1434562_at                                                  NaN
# 1424533_a_at                                                NaN
# 1434382_at    phosphatidylserine metabolic process // positi...
# ...                                                         ...
# 1422635_at    protein tetramerization // regulation of recep...
# 1429066_at                                                  NaN
# 1451566_at           regulation of transcription, DNA-dependent
# 1435193_at                                                  NaN
# 1428597_at                    regulation of Rab GTPase activity
# 1436066_at    protein amino acid phosphorylation // regulati...
# 1435445_at                                                  NaN
# 1416332_at                                   response to stress
# 1448498_at    protein kinase cascade // protein amino acid p...
# 1418107_at    regulation of transcription from RNA polymeras...
# 1423983_at                                                  NaN
# 1434509_at    signal transduction // regulation of small GTP...
# 1418174_at    transcription // regulation of cell proliferat...
# 1437464_at                                                  NaN
# 1432273_a_at  inflammatory response // signal transduction /...
# 1435854_at                                                  NaN
# 1449423_at    protein kinase cascade // protein amino acid p...
# 1429639_at    carbohydrate metabolic process // glycerol met...
# 1422660_at    translation // response to cold // gene silenc...
# 1453456_at                                                  NaN
# 1426666_a_at                      nuclear envelope organization
# 1449123_at                         hyaluronan metabolic process
# 1436766_at                                                  NaN
# 1452661_at         cellular iron ion homeostasis // endocytosis
# 1433643_at    ion transport // calcium ion transport // regu...
# 1452268_at                                                  NaN
# 1438199_at                                                  NaN
# 1426380_at                                          translation
# 1460586_at                                                  NaN
# 1415770_at                                                  NaN
#
#                                                     GO-Function  \
# Probesets
# 1440227_at    structural constituent of ribosome // transpor...
# 1438040_a_at  calcium ion binding // low-density lipoprotein...
# 1458636_at    protein binding // metal ion binding // zinc i...
# 1434228_at    calcium ion binding // magnesium ion binding /...
# 1417185_at                                                  NaN
# 1417606_a_at  calcium ion binding // sugar binding // zinc i...
# 1450768_at    protein binding // phosphatase binding // prot...
# 1416064_a_at  protein binding // nucleotide binding // ATP b...
# 1435246_at    steroid binding // receptor activity // lipid ...
# 1420886_a_at  transcription factor activity // DNA binding /...
# 1421768_a_at                                    protein binding
# 1460179_at    heat shock protein binding // metal ion bindin...
# 1456125_a_at  motor activity // protein binding // enzyme in...
# 1418587_at    protein binding // receptor activity // metal ...
# 1449431_at    calcium ion binding // protein binding // ion ...
# 1422256_at    somatostatin receptor activity // PDZ domain b...
# 1423455_at                                                  NaN
# 1460240_a_at  RNA binding // nucleic acid binding // nucleot...
# 1452462_a_at                     protein binding // DNA binding
# 1450863_a_at  transferase activity // protein kinase activit...
# 1460310_a_at  growth hormone receptor binding // hormone act...
# 1423894_a_at  aminoacyl-tRNA ligase activity // arginine-tRN...
# 1454042_a_at  magnesium ion binding // protein binding // pr...
# 1423648_at    isomerase activity // protein disulfide isomer...
# 1450061_at                     protein binding // actin binding
# 1416537_at                                  calcium ion binding
# 1416568_a_at         nucleic acid binding // nucleotide binding
# 1434562_at                                                  NaN
# 1424533_a_at                                                NaN
# 1434382_at                                                  NaN
# ...                                                         ...
# 1422635_at    hydrolase activity // protein self-association...
# 1429066_at                                                  NaN
# 1451566_at    nucleic acid binding // metal ion binding // z...
# 1435193_at                                                  NaN
# 1428597_at    calcium ion binding // Rab GTPase activator ac...
# 1436066_at    magnesium ion binding // transferase activity ...
# 1435445_at                                      protein binding
# 1416332_at    nucleic acid binding // nucleotide binding // ...
# 1448498_at    magnesium ion binding // protein binding // tr...
# 1418107_at    nucleic acid binding // transcription elongati...
# 1423983_at                                                  NaN
# 1434509_at    protein binding // guanyl-nucleotide exchange ...
# 1418174_at    transcription factor activity // DNA binding /...
# 1437464_at                                                  NaN
# 1432273_a_at  receptor activity // signal transducer activit...
# 1435854_at                                                  NaN
# 1449423_at    magnesium ion binding // protein binding // pr...
# 1429639_at    hydrolase activity // catalytic activity // ph...
# 1422660_at    RNA binding // nucleic acid binding // nucleot...
# 1453456_at                                                  NaN
# 1426666_a_at                protein binding // zinc ion binding
# 1449123_at    endopeptidase inhibitor activity // serine-typ...
# 1436766_at    protein binding // metal ion binding // zinc i...
# 1452661_at    iron ion transmembrane transporter activity //...
# 1433643_at    calcium ion binding // voltage-gated ion chann...
# 1452268_at                                                  NaN
# 1438199_at                                                  NaN
# 1426380_at    RNA binding // nucleic acid binding // nucleot...
# 1460586_at                                  calcium ion binding
# 1415770_at                                      protein binding
#
#                                                    GO-Component  \
# Probesets
# 1440227_at    ribonucleoprotein complex // ribosome // intra...
# 1438040_a_at  melanosome // endoplasmic reticulum lumen // p...
# 1458636_at                                                  NaN
# 1434228_at    mitochondrion // protein serine/threonine phos...
# 1417185_at    anchored to membrane // intracellular // exter...
# 1417606_a_at  extracellular space // MHC class I peptide loa...
# 1450768_at    endoplasmic reticulum membrane // postsynaptic...
# 1416064_a_at  endoplasmic reticulum lumen // melanosome // e...
# 1435246_at                     integral to membrane // membrane
# 1420886_a_at                                            nucleus
# 1421768_a_at  postsynaptic membrane // synapse // cytoplasm ...
# 1460179_at                                             membrane
# 1456125_a_at  microtubule // cytosol // cytoplasm // membran...
# 1418587_at                                                  NaN
# 1449431_at    integral to plasma membrane // integral to mem...
# 1422256_at    membrane fraction // plasma membrane // integr...
# 1423455_at                                              nucleus
# 1460240_a_at  spliceosome // nucleus // pronucleus // ribonu...
# 1452462_a_at                                            nucleus
# 1450863_a_at                                                NaN
# 1460310_a_at  extracellular space // extracellular region //...
# 1423894_a_at                                          cytoplasm
# 1454042_a_at                               cytoplasm // nucleus
# 1423648_at    endoplasmic reticulum lumen // melanosome // e...
# 1450061_at                            cytoplasm // cytoskeleton
# 1416537_at                     integral to membrane // membrane
# 1416568_a_at                               nucleolus // nucleus
# 1434562_at    plasma membrane // integral to membrane // mem...
# 1424533_a_at                                                NaN
# 1434382_at                     integral to membrane // membrane
# ...                                                         ...
# 1422635_at    extracellular space // synapse // extracellula...
# 1429066_at                                                  NaN
# 1451566_at                             intracellular // nucleus
# 1435193_at                                                  NaN
# 1428597_at    intracellular // integral to membrane // membrane
# 1436066_at           cytoplasm // cytoskeleton // intracellular
# 1435445_at                                              nucleus
# 1416332_at                                              nucleus
# 1448498_at                                              nucleus
# 1418107_at                                              nucleus
# 1423983_at    endoplasmic reticulum membrane // endoplasmic ...
# 1434509_at                                        intracellular
# 1418174_at                                              nucleus
# 1437464_at                                                  NaN
# 1432273_a_at                   integral to membrane // membrane
# 1435854_at    Golgi apparatus // plasma membrane // integral...
# 1449423_at    cytoplasm // cytoskeleton // plasma membrane /...
# 1429639_at                                                  NaN
# 1422660_at                                                  NaN
# 1453456_at                                                  NaN
# 1426666_a_at  nuclear envelope // nucleolus // cytoplasm // ...
# 1449123_at                                 extracellular region
# 1436766_at                                                  NaN
# 1452661_at    endosome // melanosome // extracellular region...
# 1433643_at    T-tubule // sarcoplasmic reticulum // integral...
# 1452268_at                                                  NaN
# 1438199_at                     integral to membrane // membrane
# 1426380_at                                                  NaN
# 1460586_at                     integral to membrane // membrane
# 1415770_at                                                  NaN
#
#                                                    Pathway_info  \
# Probesets
# 1440227_at                                                  NaN
# 1438040_a_at  Focal Adhesion-PI3K-Akt-mTOR-signaling pathway...
# 1458636_at                                                  NaN
# 1434228_at                        TCA Cycle:WP434(WikiPathways)
# 1417185_at                                                  NaN
# 1417606_a_at  Calcium Regulation in the Cardiac Cell:WP553(W...
# 1450768_at    Wnt Signaling Pathway NetPath:WP539(WikiPathways)
# 1416064_a_at         MAPK signaling pathway:WP493(WikiPathways)
# 1435246_at                                                  NaN
# 1420886_a_at               Insulin Signaling:WP65(WikiPathways)
# 1421768_a_at                                                NaN
# 1460179_at    Diurnally Regulated Genes with Circadian Ortho...
# 1456125_a_at                                                NaN
# 1418587_at    Oxidative Damage:WP1496(WikiPathways) // TNF-a...
# 1449431_at    XPodNet - protein-protein interactions in the ...
# 1422256_at    GPCRs, Class A Rhodopsin-like:WP189(WikiPathwa...
# 1423455_at                                                  NaN
# 1460240_a_at  GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1452462_a_at                                                NaN
# 1450863_a_at                                                NaN
# 1460310_a_at  Focal Adhesion-PI3K-Akt-mTOR-signaling pathway...
# 1423894_a_at                                                NaN
# 1454042_a_at  GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1423648_at                                                  NaN
# 1450061_at                                                  NaN
# 1416537_at                                                  NaN
# 1416568_a_at  GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1434562_at                                                  NaN
# 1424533_a_at                                                NaN
# 1434382_at                                                  NaN
# ...                                                         ...
# 1422635_at    Biogenic Amine Synthesis:WP522(WikiPathways) /...
# 1429066_at                                                  NaN
# 1451566_at                                                  NaN
# 1435193_at                                                  NaN
# 1428597_at                                                  NaN
# 1436066_at                                                  NaN
# 1435445_at                                                  NaN
# 1416332_at                  mRNA processing:WP310(WikiPathways)
# 1448498_at                 Insulin Signaling:WP65(WikiPathways)
# 1418107_at                                                  NaN
# 1423983_at                                                  NaN
# 1434509_at                                                  NaN
# 1418174_at                                                  NaN
# 1437464_at                                                  NaN
# 1432273_a_at  Non-odorant GPCRs:WP1396(WikiPathways) // Spli...
# 1435854_at                                                  NaN
# 1449423_at                                                  NaN
# 1429639_at                                                  NaN
# 1422660_at    GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1453456_at                                                  NaN
# 1426666_a_at                                                NaN
# 1449123_at                                                  NaN
# 1436766_at                                                  NaN
# 1452661_at                                                  NaN
# 1433643_at                                                  NaN
# 1452268_at                                                  NaN
# 1438199_at                                                  NaN
# 1426380_at    Focal Adhesion-PI3K-Akt-mTOR-signaling pathway...
# 1460586_at                                                  NaN
# 1415770_at                                                  NaN
#
#                                 Putative microRNA binding sites  \
# Probesets
# 1440227_at    mmu-miR-1(miRanda), mmu-miR-124(TargetScan), m...
# 1438040_a_at  mmu-miR-1(miRanda|pictar), mmu-miR-122(miRanda...
# 1458636_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1434228_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1417185_at    mmu-miR-138(miRanda), mmu-miR-15a(miRanda), mm...
# 1417606_a_at  mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1450768_at    mmu-let-7b(RNAhybrid|miRanda), mmu-let-7f(RNAh...
# 1416064_a_at  mmu-miR-1192(TargetScan|miRanda), mmu-miR-1193...
# 1435246_at    mmu-miR-124(TargetScan|miRanda), mmu-miR-124ab...
# 1420886_a_at  mmu-miR-101a(RNAhybrid|miRanda), mmu-miR-101b(...
# 1421768_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1460179_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...
# 1456125_a_at  mmu-miR-1192(miRanda), mmu-miR-143(miRanda), m...
# 1418587_at    mmu-let-7i(RNAhybrid), mmu-miR-103a(TargetScan...
# 1449431_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1422256_at    mmu-miR-129-5p(TargetScan), mmu-miR-129ab-5p(T...
# 1423455_at    mmu-let-7e(RNAhybrid), mmu-let-7i(RNAhybrid|mi...
# 1460240_a_at  mmu-let-7a(miRanda), mmu-let-7b(RNAhybrid|miRa...
# 1452462_a_at  mmu-miR-101b(RNAhybrid|miRanda), mmu-miR-10a(m...
# 1450863_a_at  mmu-miR-1(miRanda), mmu-miR-103(RNAhybrid|pict...
# 1460310_a_at                            mmu-miR-590-3p(miRanda)
# 1423894_a_at  mmu-miR-145(miRanda), mmu-miR-181b(pictar), mm...
# 1454042_a_at  mmu-miR-103(RNAhybrid|miRanda|pictar), mmu-miR...
# 1423648_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1450061_at    mmu-miR-1297(TargetScan), mmu-miR-132(miRanda)...
# 1416537_at    mmu-miR-103(pictar), mmu-miR-103a(TargetScan),...
# 1416568_a_at  mmu-let-7d(RNAhybrid|miRanda), mmu-let-7g(RNAh...
# 1434562_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1424533_a_at  mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...
# 1434382_at    mmu-miR-124(TargetScan|miRanda), mmu-miR-124a(...
# ...                                                         ...
# 1422635_at    mmu-miR-124(TargetScan), mmu-miR-124ab(TargetS...
# 1429066_at                                                  NaN
# 1451566_at    mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...
# 1435193_at    mmu-miR-134(miRanda), mmu-miR-138(miRanda), mm...
# 1428597_at    mmu-let-7c(RNAhybrid|miRanda), mmu-let-7d(RNAh...
# 1436066_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1435445_at    mmu-let-7(TargetScan), mmu-miR-101(TargetScan|...
# 1416332_at    mmu-miR-105(TargetScan), mmu-miR-106a(TargetSc...
# 1448498_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1418107_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1423983_at    mmu-miR-10b(RNAhybrid|miRanda), mmu-miR-124a(R...
# 1434509_at    mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1418174_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...
# 1437464_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...
# 1432273_a_at  mmu-miR-144(miRanda), mmu-miR-195(miRanda), mm...
# 1435854_at    mmu-miR-125a-5p(miRanda), mmu-miR-125b-5p(miRa...
# 1449423_at    mmu-miR-101a(RNAhybrid), mmu-miR-101b(RNAhybri...
# 1429639_at    mmu-let-7(TargetScan), mmu-let-7a(RNAhybrid|mi...
# 1422660_at    mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...
# 1453456_at                                                  NaN
# 1426666_a_at  mmu-miR-103(miRanda), mmu-miR-106a(miRanda), m...
# 1449123_at    mmu-miR-129-5p(RNAhybrid|miRanda), mmu-miR-145...
# 1436766_at    mmu-let-7b(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1452661_at    mmu-miR-106b(miRanda), mmu-miR-124(TargetScan|...
# 1433643_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...
# 1452268_at    mmu-let-7a(miRanda), mmu-let-7c(miRanda), mmu-...
# 1438199_at    mmu-miR-129-5p(miRanda), mmu-miR-135a(miRanda)...
# 1426380_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...
# 1460586_at    mmu-miR-103(RNAhybrid|miRanda), mmu-miR-106a(R...
# 1415770_at    mmu-miR-1(miRanda|pictar), mmu-miR-133a(miRand...
#
#                     ...           ANOVA-adjp largest fold  \
# Probesets           ...
# 1440227_at          ...         1.662375e-02     0.748667
# 1438040_a_at        ...         3.049687e-02     0.875340
# 1458636_at          ...         7.238425e-02     0.426777
# 1434228_at          ...         1.240288e-02     0.672233
# 1417185_at          ...         1.000640e-02     0.764543
# 1417606_a_at        ...         1.205508e-05     0.765267
# 1450768_at          ...         4.321327e-01     0.514687
# 1416064_a_at        ...         1.191694e-07     1.365547
# 1435246_at          ...         2.974382e-03     0.944110
# 1460310_a_at            8.258814            5.966993          2.442743
# 1423894_a_at            8.245166            5.957133          2.440724
# 1454042_a_at            8.195998            5.921608          2.433436
# 1423648_at              7.915213            5.718741          2.391389
# 1450061_at              7.493783            5.414258          2.326856
# 1416537_at              7.302306            5.275916          2.296936
# 1416568_a_at            7.184413            5.190738          2.278319
# 1434562_at              7.067301            5.106125          2.259674
# 1424533_a_at            6.998303            5.056274          2.248616
# 1434382_at              6.698640            4.839768          2.199947
# ...                          ...                 ...               ...
# 1422635_at              7.039399            5.085966          2.255209
# 1429066_at              7.214741            5.212650          2.283123
# 1451566_at              7.229191            5.223090          2.285408
# 1435193_at              7.499718            5.418546          2.327777
# 1428597_at              7.785447            5.624986          2.371705
# 1436066_at              7.815798            5.646914          2.376324
# 1435445_at              7.885954            5.697601          2.386965
# 1416332_at              7.892690            5.702469          2.387984
# 1448498_at              8.056449            5.820784          2.412630
# 1418107_at              8.482114            6.128327          2.475546
# 1423983_at              9.210999            6.654947          2.579718
# 1434509_at              9.950309            7.189098          2.681249
# 1418174_at             10.139299            7.325643          2.706593
# 1437464_at             10.345720            7.474783          2.734005
# 1432273_a_at           10.576992            7.641877          2.764394
# 1435854_at             11.309833            8.171355          2.858558
# 1449423_at             11.523889            8.326010          2.885483
# 1429639_at             11.931731            8.620676          2.936099
# 1422660_at             11.950358            8.634133          2.938390
# 1453456_at             13.685853            9.888029          3.144524
# 1426666_a_at           14.012283           10.123874          3.181804
# 1449123_at             14.651570           10.585759          3.253576
# 1436766_at             14.891396           10.759033          3.280097
# 1452661_at             16.167463           11.680992          3.417747
# 1433643_at             16.780795           12.124124          3.481971
# 1452268_at             22.000968           15.895700          3.986941
# 1438199_at             34.510174           24.933601          4.993356
# 1426380_at             38.234369           27.624332          5.255885
# 1460586_at             40.072487           28.952372          5.380741
# 1415770_at             49.924447           36.070413          6.005865
#
# [40569 rows x 59 columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM239832_AK_S.CEL', 'GSM239833_AK_S.CEL',
#        'GSM239834_AK_S.CEL', 'avg-AK_S', 'log_fold-AK_S_vs_AK_SD',
#        'fold-AK_S_vs_AK_SD', 'rawp-AK_S_vs_AK_SD', 'adjp-AK_S_vs_AK_SD',
#        'GSM239835_AK_SD.CEL', 'GSM239836_AK_SD.CEL', 'GSM239837_AK_SD.CEL',
#        'avg-AK_SD', 'GSM239838_B6_S.CEL', 'GSM239839_B6_S.CEL',
#        'GSM239840_B6_S.CEL', 'avg-B6_S', 'log_fold-B6_S_vs_B6_SD',
#        'fold-B6_S_vs_B6_SD', 'rawp-B6_S_vs_B6_SD', 'adjp-B6_S_vs_B6_SD',
#        'GSM239841_B6_SD.CEL', 'GSM239842_B6_SD.CEL', 'GSM239843_B6_SD.CEL',
#        'avg-B6_SD', 'GSM239844_D2_S.CEL', 'GSM239845_D2_S.CEL',
#        'GSM239846_D2_S.CEL', 'avg-D2_S', 'log_fold-D2_S_vs_D2_SD',
#        'fold-D2_S_vs_D2_SD', 'rawp-D2_S_vs_D2_SD', 'adjp-D2_S_vs_D2_SD',
#        'GSM239847_D2_SD.CEL', 'GSM239848_D2_SD.CEL', 'GSM239849_D2_SD.CEL',
#        'avg-D2_SD', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold',
#        '430AV2_WB_AK_Enrich', '430AV2_WB_AK_poolStDev',
#        '430AV2_WB_AK_Cohens_d', '430AV2_WB_AK_J', '430AV2_WB_AK_Hedges_g',
#        '430AV2_WB_AK_Var_d', '430AV2_WB_AK_Var_g', '430AV2_WB_AK_SEg'],
#       dtype='object')

# %% [markdown]
# ### Import key file from BioMart and index probesets to MGI gene symbols

# %%
dfX=pd.read_table('../FHS project/Sleep notebook Copy/BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[3])
 
dfX.pop('Affy mouse430 2 probeset') # remove 430V2 probeset info (not needed for 430AV2 indexing)
dfX.head(5)
# Out:
#                               Ensembl Gene ID  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ENSMUSG00000039221
# NaN                        ENSMUSG00000095611
# 1417730_at                 ENSMUSG00000061731
# 1417730_at                 ENSMUSG00000061731
# NaN                        ENSMUSG00000061731
#
#                                                                  Description  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                        predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# NaN                        exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                           MGI symbol
# Affy mouse430a 2 probeset
# 1417126_a_at                 Rpl22l1
# NaN                          Gm10597
# 1417730_at                      Ext1
# 1417730_at                      Ext1
# NaN                             Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]   # checking that no duplicate entries exist in the dataframe
# Out:
# Empty DataFrame
# Columns: [GSM239832_AK_S.CEL, GSM239833_AK_S.CEL, GSM239834_AK_S.CEL, avg-AK_S, log_fold-AK_S_vs_AK_SD, fold-AK_S_vs_AK_SD, rawp-AK_S_vs_AK_SD, adjp-AK_S_vs_AK_SD, GSM239835_AK_SD.CEL, GSM239836_AK_SD.CEL, GSM239837_AK_SD.CEL, avg-AK_SD, GSM239838_B6_S.CEL, GSM239839_B6_S.CEL, GSM239840_B6_S.CEL, avg-B6_S, log_fold-B6_S_vs_B6_SD, fold-B6_S_vs_B6_SD, rawp-B6_S_vs_B6_SD, adjp-B6_S_vs_B6_SD, GSM239841_B6_SD.CEL, GSM239842_B6_SD.CEL, GSM239843_B6_SD.CEL, avg-B6_SD, GSM239844_D2_S.CEL, GSM239845_D2_S.CEL, GSM239846_D2_S.CEL, avg-D2_S, log_fold-D2_S_vs_D2_SD, fold-D2_S_vs_D2_SD, rawp-D2_S_vs_D2_SD, adjp-D2_S_vs_D2_SD, GSM239847_D2_SD.CEL, GSM239848_D2_SD.CEL, GSM239849_D2_SD.CEL, avg-D2_SD, ANOVA-rawp, ANOVA-adjp, largest fold, 430AV2_WB_AK_Enrich, 430AV2_WB_AK_poolStDev, 430AV2_WB_AK_Cohens_d, 430AV2_WB_AK_J, 430AV2_WB_AK_Hedges_g, 430AV2_WB_AK_Var_d, 430AV2_WB_AK_Var_g, 430AV2_WB_AK_SEg]
# Index: []
#
# [0 rows x 47 columns]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average S and SD expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-SD', u'avg-S', u'log_fold-S_vs_SD']]
# df3.columns =[prefix+'avg-SD', prefix+'avg-S', prefix+'log_fold-S_vs_SD']
# df3.to_csv('input_files/430AV2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430AV2_WB_AK_Enrich',u'430AV2_WB_AK_Hedges_g', u'430AV2_WB_AK_Var_g', u'430AV2_WB_AK_SEg']]
df4.to_csv('../FHS project/Sleep notebook Copy/IPython_notebooks/input_files/430AV2_WB_AK_SymbolforIndexHedges.csv')

# %%
df4.head(10)  # check final ouput
# Out:
#                430AV2_WB_AK_Enrich  430AV2_WB_AK_Hedges_g  430AV2_WB_AK_Var_g  \
# MGI symbol
# 0610005C13Rik            -0.096293              -0.623884            0.514103
# 0610008F07Rik             0.065990               1.367883            0.637592
# 0610009B22Rik             0.263427               1.029843            0.570048
# 0610009D07Rik            -0.021945              -0.084480            0.486485
# 0610009O20Rik            -0.095423              -0.902389            0.549525
# 0610010K14Rik            -0.328433              -0.469238            0.500015
# 0610012G03Rik             0.097141               0.499229            0.552501
# 0610031J06Rik            -0.013140              -0.208273            0.485281
# 0610037L13Rik            -0.093940              -0.478124            0.500717
# 0610040J01Rik             0.099143               0.580902            0.509787
#
#                430AV2_WB_AK_SEg
# MGI symbol
# 0610005C13Rik          0.717009
# 0610008F07Rik          0.798494
# 0610009B22Rik          0.755015
# 0610009D07Rik          0.697481
# 0610009O20Rik          0.741300
# 0610010K14Rik          0.707118
# 0610012G03Rik          0.740421
# 0610031J06Rik          0.696621
# 0610037L13Rik          0.707613
# 0610040J01Rik          0.713994
